# %%
# !pip install purecpp_extract purecpp_chunks_clean
# Out:
# Requirement already satisfied: purecpp_extract in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: purecpp_chunks_clean in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: purecpp_libs in /usr/local/lib/python3.11/dist-packages (from purecpp_extract) (0.0.4)
# Requirement already satisfied: auditwheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (6.3.0)
# Requirement already satisfied: build in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (1.2.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (2.32.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (0.45.1)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (2.13.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (75.2.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean) (24.2)
# Requirement already satisfied: pyelftools>=0.24 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean) (0.32)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build->purecpp_chunks_clean) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (2025.1.31)

# %%
# !git clone https://github.com/PureAI-Tools/Tests.git # comentar isso no jupiter local
API_KEY = "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"
# Out:
# fatal: destination path 'Tests' already exists and is not an empty directory.

# %%
import purecpp_extract as ext
import purecpp_chunks_clean as cc
from purecpp_libs import DataExtractRequestStruct, LoaderDataStruct, RAGDocument

# %%
pdf_loader = ext.PDFLoader()
pdf_loader2 = ext.PDFLoader()
pdf_loader3 = ext.PDFLoader()

# %%
docxLoader = ext.DOCXLoader()
docxLoader2 = ext.DOCXLoader()

# %%
var = pdf_loader.InsertDataToExtract([
        DataExtractRequestStruct("Tests/pdfs/1984.pdf"),
        DataExtractRequestStruct("Tests/pdfs/a-christmas-carol.pdf"),
    ]) # No jupiter ta imprimindo q tao sendo achados arquivos aqui n
print(f"Content : \n {var}") # Poderia...
# Out:
# Content :
#  None

# %%
# pdf_loader2.InsertDataToExtract([DataExtractRequestStruct("pdfs")]) # deveria dar erro

# %%
pdf_loader3.InsertDataToExtract([DataExtractRequestStruct("pdfs/1984.pdf")])

# %%
docxLoader.InsertDataToExtract([
        DataExtractRequestStruct("Tests/docxs/sample1.docx"),
        DataExtractRequestStruct("Tests/docxs/sample4.docx")
    ]) # Tem que avisar que n encontra a pasta ou o arquivo na pasta se n o encontrar

# %%
docxLoader2.InsertDataToExtract([DataExtractRequestStruct("docxs")])

# %%
opt_struct = pdf_loader.GetTextContent("1984") # N retorna um tipo string
text_content = str(opt_struct)
text_content_limited = text_content[:100]
# print(text_content_limited)
for i in range(3):
  print(opt_struct.textContent[i:i+1])
  print("\n")

print(f"{len(opt_struct.textContent)} Pages")# Isso salva como paginas
# Out:
# ['Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to our free eBooks blog \r\nand email newsletter.\r\n1984\r\nBy George Orwell']
#
#
# ['\x18 1984\r\nPart One']
#
#
# ['Free eBooks at Planet eBook.com \x18\r\nChapter 1\r\nI\r\nt was a bright cold day in April, and the clocks were strik\x02ing thirteen. Winston Smith, his chin nuzzled into his \r\nbreast in an effort to escape the vile wind, slipped quickly \r\nthrough the glass doors of Victory Mansions, though not \r\nquickly enough to prevent a swirl of gritty dust from enter\x02ing along with him.\r\nThe hallway smelt of boiled cabbage and old rag mats. At \r\none end of it a coloured poster, too large for indoor display, \r\nhad been tacked to the wall. It depicted simply an enor\x02mous face, more than a metre wide: the face of a man of \r\nabout forty-five, with a heavy black moustache and rugged\x02ly handsome features. Winston made for the stairs. It was \r\nno use trying the lift. Even at the best of times it was sel\x02dom working, and at present the electric current was cut \r\noff during daylight hours. It was part of the economy drive \r\nin preparation for Hate Week. The flat was seven flights up, \r\nand Winston, who was thirty-nine and had a varicose ulcer \r\nabove his right ankle, went slowly, resting several times on \r\nthe way. On each landing, opposite the lift-shaft, the poster \r\nwith the enormous face gazed from the wall. It was one of \r\nthose pictures which are so contrived that the eyes follow \r\nyou about when you move. BIG BROTHER IS WATCHING \r\nYOU, the caption beneath it ran.\r\nInside the flat a fruity voice was reading out a list of fig-']
#
#
# 393 Pages

# %%
print(type(opt_struct))
for item in dir(opt_struct):
    print(item)
print(type(dir(opt_struct)))
# help(opt_struct)
type(opt_struct.textContent)
# Out:
# <class 'purecpp_libs.purecpp_libs.LoaderDataStruct'>
# __class__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# _pybind11_conduit_v1_
# metadata
# textContent
# <class 'list'>
# list

# %%
for attr_name in dir(opt_struct):
    if not attr_name.startswith("__"):  # Ignora atributos internos
        try:
            value = getattr(opt_struct, attr_name)
            if attr_name == "textContent":
                print(f"{attr_name}: Is a list of {len(value)} Pages")
                print(f"Page 0 {attr_name} :\n{value[0]} ")
            else:
              print(f"{attr_name}: {value}")
            print("----------------------------------------------")
        except AttributeError:
            print(f"{attr_name}: [não acessível]")
# Out:
# _pybind11_conduit_v1_: <bound method PyCapsule._pybind11_conduit_v1_ of <purecpp_libs.purecpp_libs.LoaderDataStruct object at 0x78aba86255b0>>
# ----------------------------------------------
# metadata: {'fileIdentifier': '1984'}
# ----------------------------------------------
# textContent: Is a list of 393 Pages
# Page 0 textContent :
# Download free eBooks of classic literature, books and
# novels at Planet eBook. Subscribe to our free eBooks blog
# and email newsletter.
# 1984
# By George Orwell
# ----------------------------------------------

# %%
pdf_loader.GetTextContent("1984")

# %%
if not pdf_loader3.GetTextContent("a-christmas-carol"): # DEVERIA DAR ERRO
    print("deu erro")
# Out:
# deu erro

# %%
pdf_loader3.GetTextContent("sdauhdsahudsauhdsahuds") # DEVERIA DAR ERRO

# %%
# print(type(pdf_loader))
# for item in dir(pdf_loader):
#     print(item)
# print(type(dir(pdf_loader)))

# %%
# help(pdf_loader)

# %%
items_docx = []

for fname in ["sample1", "sample4"]: # poderia ter um metodo para recuperar as listas naquela List de LoaderDataStruct < --------------- >
    x = docxLoader.GetTextContent(fname)
    if x:
        items_docx.append(x.textContent)  # cada item é um List em LoaderDataStruct
    else:
        print(f"Não foi possível extrair: {fname}")
if not items_docx:
        print("Nenhum documento foi carregado com sucesso! Encerrando.")
print(f"Total de documentos carregados: {len(items_docx)}\n")
# Out:
# Total de documentos carregados: 2

# %%
items = []
item_struct =  []

for fname in ["1984", "a-christmas-carol"]: # poderia ter um metodo para recuperar as listas naquela List de LoaderDataStruct < --------------- >
    opt_struct = pdf_loader.GetTextContent(fname)
    if opt_struct:
        items.append(opt_struct.textContent)   # cada item é um List em LoaderDataStruct
        item_struct.append(opt_struct) # cada item é LoaderDataStruct
    else:
        print(f"Não foi possível extrair: {fname}")
if not items:
        print("Nenhum documento foi carregado com sucesso! Encerrando.")
print(f"Total de documentos carregados: {len(items)}\n")
# Out:
# Total de documentos carregados: 2

# %%
print("---------------------------------------------------------")
for i, lds in enumerate(item_struct):
    print(f"--- LoaderDataStruct nº {i} ---")

    print(">> METADATA:")
    for mk, mv in lds.metadata.items():
        print(f"   {mk} => {mv}")

    print(f"\n>> TEXT CONTENT=> {lds.textContent[10][:100]} ...")
    print()
print("---------------------------------------------------------")
# Out:
# ---------------------------------------------------------
# --- LoaderDataStruct nº 0 ---
# >> METADATA:
#    fileIdentifier => 1984
#
# >> TEXT CONTENT=> Free eBooks at Planet eBook.com 11
# er of expressing himself, but even to have forgotten what it
# w ...
#
# --- LoaderDataStruct nº 1 ---
# >> METADATA:
#    fileIdentifier => a-christmas-carol
#
# >> TEXT CONTENT=> Free eBooks at Planet eBook.com 11
# ‘Under the impression that they scarcely furnish Christian chee ...
#
# ---------------------------------------------------------

# %%
# 2) CHUNKANDO COM ChunkDefault
#    (divide texto em blocos de 300 chars, com overlap=50)
# default_chunker = cc.ChunkDefault(chunk_size=300, overlap=50)
chunk_size=300
overlap=50
default_chunker = cc.ChunkDefault(chunk_size, overlap) # poderia passar o item ja aqui
default_chunker2 = cc.ChunkDefault(chunk_size, overlap)

# %%
# std::vector<RAGLibrary::Document> ProcessSingleDocument(RAGLibrary::LoaderDataStruct &item);
default_docs = default_chunker.ProcessData(item_struct[0])
# std::vector<RAGLibrary::Document> ProcessDocuments(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
default_docs2 = default_chunker2.ProcessData(item_struct, max_workers=2) # Tem q ser uma lista de purecpp_libs.purecpp_libs.LoaderDataStruct

# %%
print(f"ChunkDefault({chunk_size}, {overlap}) from  documents.size={len(default_docs)}")
print(f"ChunkDefault({chunk_size}, {overlap}) from  documents.size={len(default_docs2)}")
# Out:
# ChunkDefault(50, 10) from  documents.size=15493
# ChunkDefault(50, 10) from  documents.size=19616

# %%
# print(type(default_docs[0])) # purecpp_libs.purecpp_libs.RAGDocument
# for item in dir(default_docs[0]):
#     print(item)

# %%
# default_docs[0]
# help(default_docs)

# %%
print("-----------------------------------------------------------------------------------------")
print("default")
list_default_docs = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs)
first_n = default_docs[:3]            # primeiros 3
last_n = default_docs[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)

print("-----------------------------------------------------------------------------------------")
print("default 2")
list_default_docs2 = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs2)
first_n = default_docs2[:3]            # primeiros 3
last_n = default_docs2[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
print("-----------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------
# default
# Primeiro [0] METADATA => {'fileIdentifier': '1984'}
# Primeiro [1] METADATA => {'fileIdentifier': '1984'}
# Primeiro [2] METADATA => {'fileIdentifier': '1984'}
# Último [15490] METADATA => {'fileIdentifier': '1984'}
# Último [15491] METADATA => {'fileIdentifier': '1984'}
# Último [15492] METADATA => {'fileIdentifier': '1984'}
# -----------------------------------------------------------------------------------------
# default 2
# Primeiro [0] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Primeiro [1] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Primeiro [2] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Último [19613] METADATA => {'fileIdentifier': '1984'}
# Último [19614] METADATA => {'fileIdentifier': '1984'}
# Último [19615] METADATA => {'fileIdentifier': '1984'}
# -----------------------------------------------------------------------------------------

# %%
for i, doc in enumerate(list_default_docs):
    print(f" {i}:  {doc} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")

for i, doc in enumerate(list_default_docs2):
    print(f" {i}:  {doc} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")
# Out:
#  0:  Download free eBooks of classic literature, books  ...
# 50
#  1:  re, books and
# novels at Planet eBook. Subscribe  ...
# 50
#  2:  Subscribe to our free eBooks blog
# and email news ...
# 50
#  3:  inary work
# of translation that the final adoptio ...
# 50
#  4:  al adoption of Newspeak had been
# fixed for so la ...
# 50
#  5:   for so late a date as 2050. ...
# 28
# -----------------------------------------------------------------------------------------
#  0:  Download free eBooks of classic literature, books  ...
# 50
#  1:  re, books and
# novels at Planet eBook. Subscribe  ...
# 50
#  2:  Subscribe to our free eBooks blog
# and email news ...
# 50
#  3:  inary work
# of translation that the final adoptio ...
# 50
#  4:  al adoption of Newspeak had been
# fixed for so la ...
# 50
#  5:   for so late a date as 2050. ...
# 28
# -----------------------------------------------------------------------------------------

# %%
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_default_docs,
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])}")
    print(type(openai_emb))
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    # (c) Normalizar a primeira embedding
    print("\n\n\n")
    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
# Out:
# [EmbeddingOpeanAI] Embedding gerada com dim=1536
# <class 'list'>
# 0:
# <class 'list'>
# [0.01125139556825161, -0.025439662858843803, -0.013996444642543793, -0.028310388326644897, 0.008440200239419937, 0.02631278708577156, -0.011635040864348412, 0.0018305841367691755, -0.012666914612054825, -0.018706023693084717, 0.0026458308566361666, 0.033654965460300446, -0.008565876632928848, 0.018203316256403923, 0.010649468749761581, 0.015676546841859818, 0.025638099759817123, -0.013010872527956963, 0.004385464359074831, -0.00846004392951727, -0.0016883707139641047, 0.017885815352201462, 0.010523791424930096, -0.02342883124947548, -0.006912232842296362, -0.019513001665472984, 0.018706023693084717, -0.02889247238636017, 0.014115506783127785, -0.018997063860297203, -0.002673942595720291, -0.018401753157377243, 0.0009938401635736227, -0.03428996726870537, -0.01398321520537138, -0.008307908661663532, -0.011919467709958553, 0.005734838079661131, -0.0019479929469525814, -0.006356608588248491, 0.011734259314835072, 0.021021125838160515, -0.0015626937383785844, -0.007500930223613977, -0.019684981554746628, 0.00033052213257178664, 0.01736987940967083, -0.019499773159623146, 0.010675926692783833, 0.011727645061910152, 0.010021083988249302, 0.022092686966061592, 0.01914258487522602, -0.015888214111328125, 0.0018024721648544073, 0.011998842470347881, 0.007653065491467714, -0.0015230063581839204, 0.00331390299834311, -0.0014742237981408834, 0.0037372359074652195, -0.005602546501904726, -0.04323287308216095, -0.026934556663036346, -0.008579106070101261, 0.007507544942200184, -0.002943486673757434, 0.0015122576151043177, -0.0010434495052322745, -0.031300175935029984, 0.034369342029094696, 0.0009748232550919056, -0.018653105944395065, 0.0240109134465456, 0.02203976921737194, 0.01756831631064415, -0.016470296308398247, 0.015888214111328125, 0.011390301398932934, -0.018243003636598587, 0.0027152837719768286, -0.010107073001563549, 0.005294968839734793, -0.007434784434735775, 0.019632063806056976, -0.011793790385127068, 0.03407829999923706, 0.03177642822265625, -0.029051221907138824, -0.0330464243888855, -0.008135929703712463, -0.013652486726641655, 0.009134730324149132, 0.01431394461542368, -0.0073091075755655766, 0.001637107809074223, -0.012905039824545383, 0.013308528810739517, 0.004587208852171898, -0.020240604877471924, 0.021801644936203957, 0.0032427962869405746, -0.007110670208930969, -0.006958534941077232, -0.040163710713386536, 0.01867956481873989, 0.02276737429201603, -0.0075803049840033054, 0.012832279317080975, 0.011582124046981335, -0.029897887259721756, -0.0037240067031234503, 0.018573731184005737, -0.04632849618792534, 0.02165612392127514, -0.017092065885663033, -0.02020091749727726, -0.015557484701275826, -0.006045723333954811, -0.01207160297781229, 0.0029550623148679733, 0.020624250173568726, 0.03331100940704346, 0.0005634792614728212, -0.011939311400055885, 0.014922485686838627, -0.025691017508506775, -0.007190044969320297, -0.03167059272527695, 0.0015858447877690196, 0.016404150053858757, -0.0008111124625429511, 0.019790813326835632, -0.020081855356693268, -0.026497995480895042, 0.023838935419917107, -0.012706601992249489, 0.013969986699521542, -0.018864773213863373, 0.0012931497767567635, 0.008254991844296455, 0.0446087047457695, -0.015464880503714085, -0.009928479790687561, -0.015187068842351437, 0.02242341637611389, 0.006042415741831064, 0.0011988920159637928, 0.024950183928012848, 0.012395717203617096, 0.011066187173128128, -0.0012046798365190625, -0.002946794033050537, -0.01260076928883791, -0.010497333481907845, 0.005939890164881945, -0.0062408531084656715, 0.02422258071601391, -0.0012137748999521136, -0.02788705565035343, 0.014552068896591663, 0.010695770382881165, 0.004785646218806505, -0.020161230117082596, 0.029051221907138824, 0.024592997506260872, 0.019830500707030296, 0.010087229311466217, 0.0068857744336128235, -0.02190747857093811, -0.02639216184616089, -0.002316755475476384, -0.023521434515714645, 0.0033899706322699785, 0.014776964671909809, 0.04558766260743141, -0.003690933808684349, 0.035295382142066956, 0. ...
# 1:
# <class 'list'>
# [0.006964668165892363, -0.02638731338083744, -0.017670199275016785, -0.03064870461821556, -0.0019606566056609154, 0.027081351727247238, -0.02213980257511139, -0.02334742806851864, -0.01811438426375389, -0.014547030441462994, 0.011090722866356373, 0.026331789791584015, -0.01027175784111023, 0.0011390893487259746, 0.0015121346805244684, 0.006638470571488142, 0.01467195712029934, -0.012353871017694473, -0.0055592418648302555, -0.016337648034095764, 0.0013403602642938495, 0.016073912382125854, 0.01668466627597809, -0.02903853729367256, 0.013651722110807896, -0.0062602199614048, 0.027136873453855515, -0.02758105844259262, 0.0019328950438648462, 0.003442426910623908, 0.006752986926585436, -0.0072179920971393585, 0.008876741863787174, -0.023930419236421585, -0.011423860676586628, 0.008842040784657001, -0.013582318089902401, 0.002363198436796665, -0.003907432314008474, -0.019127679988741875, 0.03159259632229805, 0.012374692596495152, 0.0051324088126420975, -0.017961695790290833, -0.03078751266002655, -0.0013325524050742388, 0.0170594472438097, -0.012208123691380024, -0.017642438411712646, -0.003903962206095457, -0.0010245731100440025, 0.018447522073984146, -0.0009759905515238643, -0.009945560246706009, 0.011458562687039375, 0.0006081505562178791, -0.0026234625838696957, -0.009175178594887257, 0.005094236694276333, -0.0217094998806715, 0.002765740267932415, -0.007322097662836313, -0.03853297233581543, -0.00839091558009386, -0.002573144854977727, -0.0057709235697984695, -0.0036610488314181566, -0.0005344090168364346, -0.014352699741721153, -0.02279219776391983, 0.023264143615961075, 0.009903918020427227, -0.01837811805307865, 0.008564425632357597, 0.010202353820204735, -0.020821131765842438, -0.004854793660342693, 0.006905675400048494, 0.00814106222242117, -0.004587589297443628, 0.008057777769863605, -0.011187887750566006, -0.016351528465747833, 0.0006523954216390848, 0.008980847895145416, -0.008682412095367908, 0.0013047908432781696, 0.010695121251046658, -0.0034493673592805862, -0.00806471798568964, 0.009667945094406605, -0.0070653036236763, 0.005781333893537521, 0.023638924583792686, -0.024971475824713707, 0.023236382752656937, -0.02931615337729454, 0.02730344422161579, -0.0052191633731126785, -0.015893463045358658, 0.01694840006530285, 0.007974493317306042, -0.010486910119652748, -0.003364347852766514, -0.02107098512351513, 0.03728370741009712, 0.003006918355822563, -0.010729823261499405, 0.031814686954021454, 0.016323767602443695, -0.0195857435464859, -0.005666818004101515, 0.021251434460282326, -0.029427198693156242, 0.025915367528796196, -0.046583812683820724, -0.01259678415954113, -0.00493460800498724, -0.017267657443881035, -0.023028170689940453, -0.011014378629624844, 0.009376449510455132, 0.022889362648129463, -0.0020005637779831886, 0.0011685859644785523, 0.009813693352043629, -0.013776648789644241, -0.015782417729496956, -0.006978549063205719, -0.010778405703604221, 0.018086623400449753, -0.004417549818754196, 0.015018976293504238, 0.005288567394018173, -0.001329949707724154, 0.03039885126054287, -0.0038414986338466406, 0.023777732625603676, -0.02213980257511139, -0.018058860674500465, 0.019932763651013374, 0.02667880989611149, -0.021293077617883682, -0.01651809737086296, 0.0007530309376306832, 0.02560999058187008, 0.0060589490458369255, -0.003945604432374239, 0.026567762717604637, 0.01140303909778595, -0.004712515976279974, 0.007391501683741808, 0.006107531953603029, -0.02333354763686657, 0.0004162057302892208, 0.009924739599227905, -0.01298544555902481, 0.022556224837899208, -0.0007148588192649186, -0.029649291187524796, 0.026026414707303047, 0.0005855943309143186, 0.01637928932905197, -0.012916041538119316, 0.009313985705375671, 0.02452729269862175, 0.022514583542943, -0.0005643393960781395, -0.019405294209718704, -0.005566182546317577, -0.02318085916340351, 0.013630900532007217, -0.026026414707303047, 0.0068779136054217815, -0.006621119566261768, 0.0249298345297575, -0.0018426701426506042, 0.004781919997185469, -0.00957 ...
# 2:
# <class 'list'>
# [-0.004771894309669733, -0.023117326200008392, -0.0019695397932082415, -0.025199363008141518, -0.0075221979059278965, 0.027885861694812775, -0.019839797168970108, -0.02080693654716015, 0.0025891135446727276, -0.013613834977149963, -0.0047416710294783115, 0.024621764197945595, -0.01607869751751423, 0.0037476662546396255, 0.003603267017751932, 0.006998330354690552, 0.02384268119931221, -0.013647415675222874, -0.009194543585181236, -0.004644285421818495, -0.008180390112102032, 0.024259088560938835, 0.004902861081063747, -0.021666616201400757, -0.012095962651073933, -0.017596568912267685, 0.014493662863969803, -0.018765196204185486, -0.007784131448715925, -0.011175836436450481, 0.012082530185580254, 0.013539955951273441, -0.0003937400470022112, -0.013224292546510696, 0.0010871926788240671, 0.010081088170409203, -0.0011602318845689297, 0.011800447478890419, 0.008838582783937454, -0.02670380100607872, 0.02417849190533161, 0.01671002432703972, -0.0013029520632699132, -0.010517644695937634, -0.04072732850909233, -0.005611425265669823, 0.008610229939222336, -0.012747438624501228, -0.016199590638279915, 0.006437523756176233, 0.013110116124153137, 0.013513091020286083, -0.0033514078240841627, -0.004624136723577976, 0.015608560293912888, 0.020726341754198074, 0.021693481132388115, -0.014077255502343178, 0.0026142995338886976, -0.018738331273198128, -0.003781247651204467, -0.009456477127969265, -0.037208013236522675, -0.014587690122425556, -0.003808112582191825, 0.010564657859504223, -0.02087409794330597, -0.00280067534185946, -0.013036237098276615, -0.021988995373249054, 0.03425286337733269, 0.018160734325647354, -0.04489140212535858, -0.01543393824249506, 0.014977232553064823, -0.010383319109678268, -0.004110343754291534, -0.010685550980269909, -0.003781247651204467, -0.0070587764494121075, 0.014010093174874783, 0.01556826289743185, -0.013674280606210232, 0.0012937173014506698, 0.003992809448391199, -0.011068376712501049, 0.001088871737010777, 0.014789178036153316, -0.04408545047044754, -0.014614555984735489, -0.007300561759620905, -0.0088251493871212, 0.012599681504070759, 0.009993776679039001, -0.03312453627586365, 0.0036502808798104525, -0.04107657074928284, 0.011592243798077106, -0.004889428615570068, 0.0002545877650845796, 0.020269636064767838, -0.006417375057935715, -0.015796614810824394, -0.015151855535805225, -0.029847005382180214, 0.022888973355293274, 0.011370607651770115, -0.012324314564466476, 0.03167382627725601, 0.0152324503287673, -0.025253092870116234, 0.009228124283254147, 0.015971237793564796, -0.027227669954299927, 0.010410184040665627, -0.03016938641667366, -0.01812043786048889, -0.01108852494508028, -0.01850998029112816, -0.00917439442127943, 0.006044622976332903, 0.019732337445020676, 0.04188252240419388, -0.003925647120922804, 0.0009486700291745365, 0.018254762515425682, -0.012465355917811394, -0.018254762515425682, -0.015339910052716732, -0.009886316955089569, -0.0012853220105171204, 0.0065281931310892105, 0.0076766712591052055, 0.004466305021196604, -0.018469681963324547, 0.042769066989421844, -0.01346607692539692, 0.01272057369351387, -0.02480982057750225, -0.002350686816498637, 0.013412347063422203, 0.03935721144080162, -0.002055171877145767, -0.0011249715462327003, 0.02227107807993889, 0.016105562448501587, 0.022123320028185844, 0.011350459419190884, 0.03272156044840813, 0.009919898584485054, -0.0008932609925977886, 0.008334863930940628, 0.022862108424305916, -0.01848311349749565, -0.0016840992029756308, 0.0075221979059278965, -0.008596797473728657, 0.024514304473996162, 0.0017059269594028592, -0.027563482522964478, 0.01002064161002636, -0.00010210795880993828, 0.02476952224969864, -0.00014429439033847302, 0.003962586168199778, 0.02877240628004074, 0.012277301400899887, 0.002337254351004958, -0.013781741261482239, 0.011981786228716373, -0.013734727166593075, 0.0052823289297521114, -0.022915838286280632, -0.010302724316716194, 0.009093799628317356, 0.03648265823721886, -0.01945025473833084, 0.012626546435058117 ...
# 3:
# <class 'list'>
# [0.00033010472543537617, -0.004597997758537531, -0.030124325305223465, -0.002488515805453062, -0.017272602766752243, 0.01185277383774519, -0.036273881793022156, -0.010329554788768291, -0.02309625968337059, -0.01630907692015171, 0.022642837837338448, 0.022061888128519058, -0.008756741881370544, 0.008027013391256332, 0.003108430653810501, -0.0017561306012794375, 0.014013621024787426, -0.004651133436709642, -0.013149281963706017, -0.024343175813555717, -0.017726026475429535, 0.008374165743589401, -0.013723146170377731, -0.031172867864370346, 0.006454200483858585, -0.006804895121604204, 0.02537754736840725, -0.037917543202638626, -0.00392848951742053, -0.02030487172305584, -0.005958268418908119, 0.008409589529037476, -0.0030074731912463903, -0.031201206147670746, -0.028310630470514297, -0.03596215322613716, 0.0018473465461283922, -0.010775892995297909, 0.008416674099862576, 0.0004230919585097581, 0.01965307630598545, 0.002587702125310898, 0.0037726254668086767, -0.02593015693128109, -0.0072087254375219345, 0.018363652750849724, -0.01755599118769169, -0.023464666679501534, -0.026312733069062233, -0.0041693709790706635, 0.0063337599858641624, 0.026227716356515884, -0.026922021061182022, -0.0031385410111397505, -0.01850534789264202, -0.0020244652405381203, 0.001495766220614314, 0.014523722231388092, -0.000925444473978132, 0.012497485615313053, 0.0002820613153744489, -0.006432946305721998, -0.01748514361679554, 0.028594020754098892, -0.002235236344859004, 0.001257541822269559, 0.009096809662878513, 0.014566230587661266, -0.009925724007189274, -0.013694806955754757, 0.03652893379330635, -0.004091438837349415, -0.006014946382492781, 0.013708977028727531, 0.0451156385242939, -0.009181826375424862, 0.019865617156028748, -0.01292965468019247, -0.012759621255099773, 0.0072051831521093845, 0.026241885498166084, -0.03658561035990715, 0.005873251706361771, -2.4658223992446437e-05, 0.01381524745374918, -0.0002643494517542422, -0.03307157754898071, 0.016181550920009613, -0.020999176427721977, -0.010867995209991932, 0.010279960930347443, 0.013673553243279457, 0.003087176475673914, 0.02697869949042797, -0.0038257609121501446, -0.004392540547996759, -0.007601928897202015, 0.034545205533504486, -0.024584056809544563, -0.01130016427487135, 0.0017375331372022629, -0.0036592695396393538, -0.01210782490670681, -0.013177621178328991, -0.011363927274942398, -0.011172639206051826, -0.0024158970918506384, 0.015898162499070168, 0.02190602384507656, -0.02302541397511959, -0.01462290808558464, 0.04891306161880493, -0.018703719601035118, -0.023804735392332077, 0.010535011999309063, -0.04214004799723625, 0.005395031534135342, -0.0004932751762680709, -0.01578480564057827, -0.005402116104960442, 0.017159245908260345, 0.01460873894393444, 0.02755964919924736, -0.021693481132388115, 0.022812871262431145, 0.04182831943035126, -0.0024973717518150806, -0.0026443800888955593, -0.03661394864320755, -0.021849345415830612, 0.010712130926549435, 0.006383352912962437, 0.01435368787497282, 0.01069796085357666, -0.021849345415830612, 0.02141009271144867, 0.00981236808001995, 0.00783572532236576, 0.001270825625397265, -0.019879788160324097, 0.03270317241549492, 0.0224728025496006, -0.03879604861140251, 0.004328777547925711, 0.017173415049910545, -0.00041423604125157, 0.013857756741344929, 0.009231419302523136, 0.006131844595074654, 0.006539217196404934, -0.01131433341652155, -0.010981351137161255, 0.029642563313245773, -0.02248697355389595, 0.0140490448102355, 0.019922295585274696, 0.007254776079207659, 0.013156366534531116, -0.00650379341095686, 0.00925975851714611, -0.0022068973630666733, -0.00042663433123379946, -0.014374942518770695, 0.00022914714645594358, 0.022359447553753853, 0.022345278412103653, 0.004955777432769537, -0.009025962091982365, 0.0075806742534041405, -0.025533411651849747, -0.018972940742969513, 0.005805946420878172, -0.007587759289890528, 0.02753130905330181, 0.020446566864848137, 0.0026355241425335407, 0.01439619716256857, 0.011186808347702026, -0.0290757 ...
# 4:
# <class 'list'>
# [0.0030253273434937, 0.015140642412006855, -0.0002945667365565896, -0.0067404573783278465, -0.015322722494602203, 0.007626345846801996, -0.026611674576997757, -0.0007243803120218217, -0.03974943980574608, -0.017017465084791183, 0.0304773710668087, 0.018964320421218872, 0.02170952409505844, 0.0010644670110195875, 0.004096797201782465, -0.0007567694992758334, 0.007402247283607721, 0.015308716334402561, 0.00349978543817997, -0.0067334542982280254, -0.009482160210609436, 0.016667312011122704, -0.015056605450809002, -0.01668131910264492, -0.006365792825818062, -0.029608989134430885, 0.015420765615999699, -0.02944091707468033, -0.00012386684829834849, 0.005637473426759243, 0.00572851300239563, -0.008774849586188793, -0.02614947222173214, -0.01135198026895523, -0.0456320196390152, -0.01812395080924034, -0.0183760616928339, -0.032354194670915604, 0.017885847017169, -0.02261992357671261, 0.0045344894751906395, 0.001128370058722794, 0.014552384614944458, -0.023670384660363197, -0.021191297098994255, 0.00023547830642201006, -0.0023722907062619925, -0.007437262684106827, -0.00784344132989645, -0.0056724888272583485, 0.002339026192203164, 0.03297046571969986, -0.03238220512866974, -0.017465662211179733, -0.004331400152295828, -0.00819359440356493, 0.012185346335172653, 0.004891646094620228, 0.0002210344682680443, -0.015658870339393616, -0.013424890115857124, -0.0023880477529019117, -0.00881686806678772, 0.03750845417380333, -0.005966617725789547, -8.75931145856157e-05, 0.005970119033008814, -0.0021324355620890856, 0.00028034174465574324, 0.00035956400097347796, 0.03501536324620247, -0.002573629142716527, 0.004012760240584612, -0.0156868826597929, 0.0035820715129375458, 0.008508732542395592, 0.012213358655571938, -0.004590514115989208, -0.0027364506386220455, 0.010154454968869686, 0.02315215766429901, -0.015196667052805424, -0.005721509922295809, 0.022185733541846275, 0.02495894953608513, -0.015967005863785744, -0.005917596165090799, 0.026555649936199188, -0.010084424167871475, 0.0006175834569148719, 0.004702562931925058, 0.010763722471892834, 0.013782046735286713, 0.003188148606568575, -0.024076562374830246, 0.015392753295600414, 0.00300606875680387, 0.02728397026658058, -0.026065435260534286, -0.011204916052520275, 0.003030579537153244, -0.01584094949066639, -0.01743764989078045, -0.005644476506859064, -0.007451268844306469, 0.012710575945675373, -0.0007195656653493643, 0.006978561636060476, 0.00789246242493391, -0.016695324331521988, -0.010889777913689613, 0.05185074731707573, 0.029300855472683907, -0.017591718584299088, 0.01862817257642746, -0.05154261365532875, -0.01956658437848091, -0.029945136979222298, -0.009391119703650475, -0.010630663484334946, 0.0170314721763134, 0.019300468266010284, 0.026569657027721405, -0.00036678591277450323, 0.007857447490096092, 0.008151575922966003, -0.017969883978366852, 0.017199546098709106, -0.030365321785211563, -0.0038411852438002825, 0.01642920821905136, 0.01862817257642746, 0.05493209883570671, 0.0014758975012227893, -0.015532814897596836, 0.03515542298555374, -0.0051997811533510685, 0.002302260138094425, -0.020981205627322197, -0.0331665500998497, 0.015028593130409718, 0.021485425531864166, -0.0014627667842432857, 0.008669803850352764, 0.003767652902752161, 0.016009023413062096, -0.0032546778675168753, 0.008158579468727112, 0.010868768207728863, -0.014314279891550541, -0.00011719203757820651, -0.009538184851408005, -0.0037081267219036818, -0.00242131226696074, 0.00881686806678772, 0.01623312197625637, 0.012976692989468575, 0.016807373613119125, -0.013053727336227894, -0.006029645446687937, -0.012122318148612976, 0.00871182233095169, 0.0121013093739748, 0.007745398208498955, 0.016107065603137016, 0.022942064329981804, 0.01549079641699791, -0.009601212106645107, 0.008508732542395592, -0.013915104791522026, -0.008242616429924965, 0.004481966141611338, -0.010994823649525642, 0.016457220539450645, 0.03232618048787117, 0.02007080614566803, -0.0057775345630943775, 0.008151575922966003, -0.00930008012801 ...
# 5:
# <class 'list'>
# [-0.011320785619318485, -0.031912557780742645, 0.005395794752985239, 0.004035960882902145, 0.01843479461967945, -0.01236578170210123, -0.02191811241209507, -0.0004203427815809846, -0.037834201008081436, 0.020404210314154625, 0.009699703194200993, 0.008842270821332932, -0.007629807572811842, 0.0039053361397236586, -0.011026043444871902, -0.00714080361649394, 0.025187073275446892, -0.007093912456184626, 0.025455022230744362, -0.008547528646886349, 0.011957161128520966, -0.030385257676243782, 0.013464367017149925, -0.008353265933692455, 0.003386187832802534, -0.015648139640688896, -0.00034456385765224695, -0.018568769097328186, 0.015085449442267418, 0.006561366841197014, 0.019854916259646416, -0.009190602228045464, -0.0002689942775759846, -0.026366043835878372, -0.018421396613121033, -0.024972716346383095, -0.005931689869612455, -0.011568637564778328, 0.0533483661711216, -0.021502794697880745, 0.002629235852509737, 0.0004362521867733449, 0.0005744126392528415, -0.0005610152729786932, -0.027893343940377235, 0.0066015589982271194, 0.023056890815496445, -0.024865536019206047, 0.006621655076742172, 0.010168611072003841, 0.03279678523540497, 0.00868150219321251, -0.026901938021183014, -0.03837009519338608, 0.019774531945586205, -0.00352686014957726, -0.022869328036904335, 0.02355259284377098, -0.023887528106570244, -0.009880567900836468, 0.009297781623899937, -0.0062364800833165646, -0.011789694428443909, 0.010349475778639317, -0.014348593540489674, -0.008420253172516823, -0.0454707071185112, 0.006758978124707937, -0.004575205035507679, -0.0008926004520617425, 0.023311439901590347, 0.011347580701112747, 0.04289840906858444, -0.008025030605494976, 0.024637781083583832, 0.008326471783220768, 0.010396366938948631, -0.023994706571102142, -0.0025354542303830385, -0.0006183728110045195, 0.017550567165017128, -0.02576316148042679, -0.0016897445311769843, 0.008092017844319344, 0.019225239753723145, 0.00041950546437874436, 0.011561938561499119, 0.020297029986977577, -0.007060419302433729, 0.008467144332826138, 0.03440447151660919, -0.0004864923539571464, -0.006732183508574963, 0.027920139953494072, -0.002691198606044054, 0.004401039332151413, 0.010342776775360107, 0.012948567979037762, 0.0012459562858566642, -0.02136882022023201, 0.008607816882431507, 0.02072574570775032, -0.00862121395766735, -0.00011262172483839095, -0.0013003831263631582, 0.004813008476048708, 0.019412802532315254, 0.026232069358229637, 0.03285037353634834, -0.022226253524422646, -0.011300689540803432, 0.0292062871158123, 0.019466392695903778, -0.023405222222208977, 0.014040454290807247, -0.04493481293320656, -0.008413554169237614, 0.02968859300017357, -0.014094043523073196, -0.015487371012568474, 0.015594550408422947, 0.0062532271258533, 0.0125064542517066, -0.009190602228045464, 0.0063001178205013275, -0.01314282976090908, -0.023298043757677078, 0.009003039449453354, -0.019694147631525993, -0.002550526289269328, -0.002486888552084565, -0.0017416593618690968, -0.006403947714716196, 0.012827991507947445, 0.01771133579313755, 0.014549554325640202, -0.0500258170068264, 0.007730287965387106, -0.02574976347386837, -0.04174623638391495, 0.006604908034205437, 0.03901316970586777, -0.020765937864780426, 0.02290952019393444, -0.031189100816845894, -0.0028938341420143843, -0.0029943143017590046, 0.00967290811240673, -8.561762660974637e-05, -0.02091331034898758, 0.014295004308223724, 0.015232820995151997, 0.0008833897300064564, -0.003540257690474391, 0.0016085229581221938, -0.0013765807962045074, 0.009465249255299568, 0.003928781487047672, 0.017229029908776283, -0.02529425360262394, -0.015206025913357735, -0.01164232287555933, 0.014804104343056679, 0.011340881697833538, 0.016599353402853012, 0.011106427758932114, 0.01438878569751978, 0.0012225109385326505, 0.00817240122705698, -0.016853904351592064, -0.0090901218354702, 0.03239486366510391, -0.000823101494461298, -0.0020548230968415737, -0.0043541486375033855, 0.03223409503698349, -0.0027431135531514883, -0.0060757119208574295, -0.01 ...

# %%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 3) CHUNKANDO COM ChunkCount (divide texto a cada pontuação final, usando regex, overlap menor)
# ChunkCount(const std::string &count_unit, const int overlap = 600, const int count_threshold = 1);
count_chunker = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)
count_chunker2 = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)

# %%
# std::vector<RAGLibrary::Document> ProcessData(RAGLibrary::LoaderDataStruct &item);
count_docs = count_chunker.ProcessData(item_struct[0])
# std::vector<RAGLibrary::Document> ProcessData(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
count_docs2 = count_chunker2.ProcessData(item_struct, max_workers=5)

# %%
print(f"ChunkCount from {len(count_docs)}")
print(f"ChunkCount2 from {len(count_docs2)}")
# Out:
# ChunkCount from 6914
# ChunkCount2 from 8857

# %%
print("-----------------------------------------------------------------------------------------")
print("Count")
list_count_docs = []
prev_m = None
for i, doc in enumerate(count_docs):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata

print("-----------------------------------------------------------------------------------------")
print("Count 2")
list_count_docs2 = []
prev_m = None
for i, doc in enumerate(count_docs2):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs2.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata
print("-----------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------
# Count
#  METADATA => {'fileIdentifier': '1984'}
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 0:  Document(metadata={"fileIdentifier":"1984"}, page_content="Download free eBooks of classic literature, books and
# novels at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 1:  Document(metadata={"fileIdentifier":"1984"}, page_content="net eBook. Subscribe to our free eBooks blog
# and email newsletter.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 2:  Document(metadata={"fileIdentifier":"1984"}, page_content="ewsletter.
# 1984
# By George Orwell
#  1984
# Part One
# Free eBooks at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 3:  Document(metadata={"fileIdentifier":"1984"}, page_content="net eBook.com
# Chapter 1
# I
# t was a bright cold day in April, and the clocks were striking th...")
# -----------------------------------------------------------------------------------------
# Count 2
#  METADATA => {'fileIdentifier': 'a-christmas-carol'}
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 0:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="Download free eBooks of classic literature, books and
# novels at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 1:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="net eBook. Subscribe to our free eBooks blog
# and email newsletter.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 2:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="ewsletter.
# A Christmas Carol
# By Charles Dickens
#  Sons and Lovers
# I have endeavoured in this G...")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 3:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="
# with me. May it haunt their houses pleasantly, and no one
# wish to lay it.")
# -----------------------------------------------------------------------------------------

# %%
for i, doc in enumerate(list_count_docs):
    print(f" {i}:  {doc[:70]} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")

for i, doc in enumerate(list_count_docs2):
    print(f" {i}:  {doc[:70]} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")
# Out:
#  0:  Download free eBooks of classic literature, books and
# novels at Plan ...
# 79
#  1:  net eBook. Subscribe to our free eBooks blog
# and email newsletter. ...
# 68
#  2:  ewsletter.
# 1984
# By George Orwell
#  1984
# Part One
# Free eBooks at Pla ...
# 80
#  3:  net eBook.com
# Chapter 1
# I
# t was a bright cold day in April, and t ...
# 104
# -----------------------------------------------------------------------------------------
#  0:  Download free eBooks of classic literature, books and
# novels at Plan ...
# 79
#  1:  net eBook. Subscribe to our free eBooks blog
# and email newsletter. ...
# 68
#  2:  ewsletter.
# A Christmas Carol
# By Charles Dickens
#  Sons and Lovers
# I ...
# 261
#  3:
# with me. May it haunt their houses pleasantly, and no one
# wish to  ...
# 77
# -----------------------------------------------------------------------------------------

# %%
# 4) USANDO ALGUMAS FUNÇÕES DE CHUNKCOMMONS MANUALMENTE
#    Exemplo:  (a) Dividir manualmente um texto e (b) Gerar embeddings via OpenAI
#    (c) Normalizar e exibir a embedding

# (a) SplitText manual
text_example = ["Este é um texto de exemplo.", "Ele será unido e fatiado em 50 chars com 10 de overlap."]
splitted = cc.SplitText(text_example, overlap=10, chunk_size=50)
print(f"[SplitText] Gerei {len(splitted)} pedaços. Primeiro pedaço:\n   {splitted[0]}")
# Out:
# [SplitText] Gerei 3 pedaços. Primeiro pedaço:
#    Este é um texto de exemplo.
# Ele será unido e fat

# %%
# 5) USANDO FUNÇÕES DE EMBEDDINGS MANUALMENTE
#    Exemplo:  (a) Gerar embeddings via OpenAI
#    (b) Normalizar e exibir a embedding
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_count_docs, # tem q ser uma lista de string
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])} ")
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
# Out:
# [EmbeddingOpeanAI] Embedding gerada com dim=1536
# 0:
# <class 'list'>
# [0.010966859757900238, -0.032128263264894485, -0.010839260183274746, -0.025882594287395477, 0.003952233120799065, 0.0321819894015789, -0.01642678491771221, 0.002850846154615283, -0.01635962724685669, -0.020603995770215988, -0.002849167212843895, 0.01930113509297371, -0.012195846065878868, 0.01568804867565632, 0.016950614750385284, 0.023505210876464844, 0.01918025128543377, -0.024566302075982094, -0.012645803391933441, -0.0005213120020925999, 0.006923963315784931, 0.03032843768596649, 0.0032840135972946882, -0.03666812926530838, -0.0014472493203356862, -0.022618727758526802, 0.02358580008149147, -0.03040902689099312, 0.018978778272867203, -0.014667251147329807, 0.001997942803427577, -0.0007068352424539626, 0.01437175739556551, -0.031188055872917175, -0.0022816844284534454, 0.001152594806626439, -0.0002087136817863211, 0.016776004806160927, -0.0012608866672962904, -0.015795500949025154, 0.020348796620965004, 0.010254987515509129, 0.0012012841179966927, -0.008065644651651382, -0.03505634143948555, 0.0054968614131212234, 0.018992209807038307, -0.006316185928881168, 0.005809145048260689, 0.005933386739343405, -0.006688911467790604, 0.026822803542017937, 0.023760410025715828, -0.0333908312022686, 0.0012936260318383574, -0.0016420067986473441, 0.0014019178925082088, -0.010194545611739159, 0.008401433937251568, -0.007085141725838184, 0.007031415589153767, -1.7051770839771052e-07, -0.03545928746461868, -0.02500954456627369, -0.010066946037113667, 0.006400133017450571, -0.005503577180206776, 0.0009905766928568482, 0.001441373024135828, -0.02664819359779358, 0.0434107668697834, 0.017649054527282715, -0.016561100259423256, 0.013230075128376484, 0.020026439800858498, 0.009496104903519154, -0.0055908821523189545, 0.007145584095269442, 0.0016008727252483368, -0.006541164126247168, 0.006698985118418932, -0.01315620169043541, 0.0025167365092784166, -0.007380635943263769, 0.009462526068091393, -0.020160755142569542, 0.017716212198138237, 0.02604377269744873, -0.02419021911919117, -0.02710486575961113, -0.006944110617041588, -0.014237442053854465, 0.016681984066963196, 0.023505210876464844, -0.010221408680081367, 0.012686097994446754, -0.019233977422118187, 0.02024134434759617, 0.0015026545152068138, -0.024485712870955467, 0.017232676967978477, 0.0023454842157661915, 0.005359187722206116, -0.00519129354506731, -0.028877830132842064, 0.034680258482694626, 0.022027740254998207, -0.0013582654064521194, 0.015728343278169632, 0.015029902569949627, -0.026997413486242294, 0.0023203000891953707, 0.01720581389963627, -0.033766914159059525, 0.01772964373230934, -0.03172531723976135, -0.018038570880889893, -0.009408799931406975, -0.010953428223729134, -0.012719676829874516, -0.006312828045338392, 0.011792900040745735, 0.03403554484248161, -0.0032940872479230165, -0.007219457533210516, 0.012800266034901142, -0.013411401771008968, -0.015916384756565094, -0.027480948716402054, 0.006158364936709404, 0.020845763385295868, 0.006819868925958872, 0.022242644801735878, -0.013021886348724365, -0.029629996046423912, 0.020295070484280586, 0.00130873650778085, 0.0058326502330601215, -0.022739611566066742, -0.0016520804492756724, 0.0063833435997366905, 0.03524438291788101, -0.010087093338370323, -0.009852040559053421, -0.008374570868909359, 0.03505634143948555, 0.0038481387309730053, 0.0005049422616139054, 0.03347142040729523, 0.01255178265273571, 0.006410206668078899, 0.016346195712685585, -0.01093999668955803, -0.02282020077109337, -0.00877080112695694, 0.014573230408132076, -0.01378076896071434, 0.03693675994873047, 0.011846626177430153, -0.03134923428297043, 0.013941947370767593, 0.009596841409802437, 0.014747840352356434, -0.007783582434058189, 0.01903250440955162, 0.025573669001460075, 0.021866561844944954, -0.0038145598955452442, -0.0012843918520957232, -0.019744375720620155, -0.04813867062330246, 0.0006275051855482161, -0.019704081118106842, 0.005543871782720089, 0.008482023142278194, 0.038548544049263, -0.010738523676991463, 0.02300824224948883, -0.000669898465 ...
# 1:
# <class 'list'>
# [-0.004422593861818314, -0.04042739048600197, -0.0012565728975459933, -0.03169073536992073, -0.0004739704600069672, 0.022180801257491112, -0.01534341648221016, -0.018857071176171303, -0.016455847769975662, -0.010256076231598854, -0.005874181631952524, 0.019942371174693108, -0.01603529416024685, 0.005077165085822344, 0.002079026075080037, 0.020661382004618645, 0.010398522019386292, -0.01591319777071476, 0.004015606828033924, -0.004890629090368748, -0.014298815280199051, 0.03160933777689934, 0.006772944703698158, -0.02245212532579899, -0.005752085242420435, -0.011761928908526897, 0.010228944011032581, -0.010981869883835316, -0.0031049728859215975, -0.015614740550518036, 0.01589963212609291, 0.012338493950664997, -0.0075767445378005505, -0.016048859804868698, 0.0032033282332122326, 0.01843651942908764, 0.0024198777973651886, 0.0012404629960656166, 0.005596073344349861, -0.019983069971203804, 0.023523857817053795, 0.009035115130245686, -0.0015991204418241978, -0.00706801051273942, -0.02862476371228695, 0.0034763487055897713, 0.014583706855773926, -0.020797044038772583, -0.006474487483501434, 0.006528752390295267, 0.005026291590183973, 0.01155843585729599, 0.010174678638577461, -0.010859774425625801, 0.013878262601792812, 0.014855031855404377, 0.008424634113907814, -0.023659519851207733, 0.010045799426734447, -0.017473315820097923, -0.008621344342827797, 0.001605903496965766, -0.035435017198324203, -0.014855031855404377, -0.008492465130984783, -0.005229785107076168, -0.014407346025109291, 0.0076174428686499596, -0.017120594158768654, -0.02962866611778736, 0.03065969981253147, 0.025680890306830406, -0.03331868350505829, -0.008648477494716644, 0.017012063413858414, -0.009252174757421017, -0.009353921748697758, -0.010900473222136497, 0.005745301954448223, -0.0015541822649538517, 0.009252174757421017, 0.008723091334104538, -0.017459750175476074, -0.0039545586332678795, 0.0016355796251446009, -0.020335791632533073, 0.00738003384321928, 0.009360704571008682, -0.036927301436662674, -0.004788882099092007, -0.0016949319979175925, 0.001924710115417838, 0.02104123681783676, 0.015940330922603607, -0.019616780802607536, 0.010262859985232353, -0.02403937466442585, 0.014868597500026226, -0.010785159654915333, -0.0034203878603875637, 0.02231646329164505, 0.0011887416476383805, -0.010724111460149288, -0.011463471688330173, -0.029221678152680397, 0.02494831383228302, 0.016998497769236565, -0.008444983512163162, 0.03150080516934395, 0.02150248922407627, -0.024012243375182152, 0.00978804100304842, 0.01821945793926716, -0.029601532965898514, 0.018002398312091827, -0.026739057153463364, -0.011029352433979511, -0.0200509000569582, -0.006677981000393629, -0.011124315671622753, -0.002999834483489394, 0.023957977071404457, 0.04769889637827873, -0.0123045789077878, 0.0004230970807839185, 0.025708023458719254, -0.003081232076510787, -0.01550621073693037, -0.011972205713391304, -0.005762259941548109, 0.009374271146953106, 0.007162974216043949, 0.008512814529240131, 0.006403264589607716, -0.022302895784378052, 0.03983047604560852, -0.0026318503078073263, 0.00506699038669467, -0.029818592593073845, -0.0069526974111795425, 0.020512152463197708, 0.0377684086561203, -0.011802627705037594, -0.0048872376792132854, 0.028679028153419495, 0.027892187237739563, 0.01534341648221016, 0.017025629058480263, 0.044470131397247314, 0.01900630071759224, -0.006121765356510878, 0.0075767445378005505, 0.018233025446534157, -0.01946755312383175, -0.0017805688548833132, 0.010968304239213467, -0.001496525714173913, 0.026698358356952667, 0.005541808437556028, -0.024446362629532814, 0.009482800960540771, 0.008946934714913368, 0.014312381856143475, -0.004202142357826233, 0.006559276487678289, 0.035082291811704636, 0.010446003638207912, -0.011239629238843918, -0.007875201292335987, 0.01362728700041771, -0.013891828246414661, 0.010201811790466309, -0.033128753304481506, -0.0029574399814009666, 0.0013642548583447933, 0.04015606641769409, -0.012101084925234318, 0.01362728700041771, -0.001038 ...
# 2:
# <class 'list'>
# [0.001418618019670248, -0.024963701143860817, -0.028461799025535583, -0.035113487392663956, 0.007744842674583197, 0.01160070113837719, -0.0221678726375103, -0.004604504443705082, -0.0206043291836977, -0.027587274089455605, 0.009195758029818535, 0.04075814411044121, -0.04054613783955574, 0.0012703794054687023, 0.012256594374775887, 0.03898259624838829, 0.032039400190114975, -0.010606923140585423, 0.013873139396309853, -0.005846726708114147, 0.005187520757317543, 0.02492395043373108, -0.005336587317287922, -0.03156238794326782, 0.004269932396709919, -0.025493716821074486, 0.024340933188796043, -0.042851705104112625, 0.03174789249897003, -0.025374462828040123, -0.00011966742749791592, -0.014588659629225731, -0.014310401864349842, -0.004478625953197479, -0.028064288198947906, -0.004246744327247143, -0.0002583822642918676, -0.008175479248166084, 0.02748127281665802, -0.028064288198947906, 0.029998842626810074, 0.022817140445113182, -0.007075698580592871, 0.010176286101341248, -0.040122125297784805, 0.01886853016912937, 0.025851476937532425, -0.021359600126743317, -0.010414792224764824, 0.007108824793249369, 0.014906669035553932, 0.017225483432412148, -7.867408385209274e-06, -0.0385320819914341, -0.011786205694079399, 0.010447918437421322, 0.009016877971589565, 0.002992927795276046, -0.005064954981207848, -0.02798478677868843, 0.014045394957065582, -0.007320830598473549, -0.03039635345339775, -0.017225483432412148, -0.022817140445113182, -0.004949014168232679, -0.016788221895694733, 0.02338690683245659, -0.012713732197880745, -0.01046779379248619, 0.04727732762694359, 0.011488072574138641, -0.00014741039194632322, 0.007784593850374222, 0.01374063640832901, -0.012779983691871166, -0.017463991418480873, 0.006323740351945162, -0.003551099682226777, -0.009997406043112278, 0.010852054692804813, -0.012395722791552544, 0.011640451848506927, 0.013416001573204994, 0.005220646504312754, 0.002284032991155982, 0.003228121902793646, 0.029442327097058296, -0.028276294469833374, -0.01066654920578003, -0.021187344565987587, -0.010832179337739944, 0.0062276748940348625, 0.012680605985224247, -0.03450397029519081, 0.007936973124742508, -0.02163785696029663, 0.03384144976735115, -0.0016910787671804428, -0.03439796715974808, 0.01958405040204525, -0.009679396636784077, -0.028726806864142418, -0.0021747173741459846, -0.021743860095739365, 0.016072701662778854, 0.030846865847706795, 0.0006277363863773644, 0.010103409178555012, -0.0004939904320053756, -0.013674383983016014, -0.0018699588254094124, 0.022194374352693558, -0.032887425273656845, 0.028620803728699684, -0.03707453981041908, -0.006396617274731398, -0.020856086164712906, -0.02901831455528736, -0.020365821197628975, 0.002032275777310133, 0.03985711932182312, 0.03521949052810669, -0.007075698580592871, 0.00971914827823639, -0.004349434748291969, -0.028965312987565994, 0.004210305865854025, -0.0240494254976511, -0.005790412425994873, 0.038240574300289154, 0.008791621774435043, 0.02595747821033001, -0.0046740686520934105, -0.021518604829907417, 0.02338690683245659, -0.02166435867547989, 0.012163842096924782, -0.020551327615976334, -0.01168020348995924, 0.03389445319771767, 0.017994005233049393, 0.004647567868232727, 0.011613951064646244, 0.008917500264942646, 0.024976952001452446, 0.006744439247995615, 0.00816222932189703, 0.005992481019347906, -0.0025689159519970417, -0.0022360002622008324, 0.008791621774435043, 0.008314608596265316, 0.0018798965029418468, -0.007930347695946693, 0.029468826949596405, -0.0013507098192349076, 0.03129737824201584, -0.00610179640352726, -0.014098395593464375, 0.01244209986180067, 0.007890596985816956, 0.023068897426128387, -0.013548505492508411, 0.01753024198114872, 0.0319598987698555, 0.029097817838191986, 0.010514169931411743, -0.0010053720325231552, -0.0031834018882364035, -0.031694889068603516, 0.025162456557154655, -0.02663324773311615, 0.005263710394501686, 0.022631635889410973, 0.05424702540040016, 0.0016521557699888945, 0.010640048421919346, 0.001319240196608007, ...
# 3:
# <class 'list'>
# [-0.005840199999511242, -0.020346075296401978, -0.013227605260908604, -0.05171515420079231, 0.006759890355169773, 0.019628915935754776, -0.015684539452195168, -0.012410840019583702, -0.0315815694630146, -0.01757040247321129, 0.00836021825671196, 0.02061169035732746, -0.024569345638155937, 0.003921134863048792, -0.0005108930054120719, 0.0013538041384890676, 0.003134251805022359, -0.022842852398753166, 0.0015530150849372149, -0.006212060339748859, -0.0063481880351901054, 0.034503329545259476, -0.009309790097177029, -0.008778560906648636, -0.001367084914818406, -0.005338852759450674, 0.008121165446937084, -0.02548571676015854, 0.0315018855035305, -0.018951598554849625, -0.00023946812143549323, -0.029801953583955765, -0.009150421246886253, -0.012835822999477386, -0.024343574419617653, -0.019084405153989792, -0.0066636051051318645, -0.024224046617746353, 0.003937735687941313, -0.02209913171827793, 0.0066636051051318645, 0.01989453099668026, -0.008825043216347694, -0.001812819391489029, -0.04372015595436096, 0.03468926250934601, 0.032219044864177704, -0.0007906183018349111, -0.0034430287778377533, 0.025777893140912056, 0.017092296853661537, 0.02644192986190319, 0.0056609101593494415, -0.028022335842251778, -0.0029151197522878647, 0.012112023308873177, 0.009821098297834396, 0.010033589787781239, -0.010817152447998524, -0.012384278699755669, -0.013745552860200405, -0.009694931097328663, -0.033706486225128174, -0.01824771985411644, 0.007789147086441517, -0.01997421495616436, -0.019363300874829292, 0.00034052616683766246, -0.01602983847260475, -0.00256152031943202, 0.0469340905547142, 0.0116139966994524, -0.005584545899182558, 0.013572904281318188, 0.011315179988741875, 0.0006246092380024493, -0.0037883275654166937, -0.006285104434937239, 0.004850785713642836, -0.0027823124546557665, 0.019403142854571342, -0.02850044146180153, -0.008028199896216393, 0.015286117792129517, 0.008884807117283344, -0.01155423279851675, -0.00804148055613041, 0.007058707065880299, -0.02235146425664425, 0.005999568849802017, 0.01977500319480896, -0.002432033186778426, 0.024489661678671837, 0.020239830017089844, -0.010717547498643398, 0.011023004539310932, -0.012543647550046444, 0.003711963538080454, 0.0013612746261060238, -0.022776449099183083, 0.026216156780719757, -0.008725438266992569, -0.01418381743133068, 0.0012616690946742892, -0.02850044146180153, 0.0057970378547906876, 0.03235185146331787, 0.00021332169126253575, 0.0026495051570236683, -0.014502555131912231, -0.018672702834010124, 0.024821680039167404, 0.007722743321210146, -0.029509777203202248, 0.01640169881284237, -0.034822069108486176, -0.002584761707112193, -0.022404586896300316, -0.00618881918489933, -0.0015721061499789357, -0.005455058999359608, 0.047491881996393204, 0.010604660958051682, 0.005162883084267378, 0.0019506069365888834, -0.012311235070228577, -0.010365608148276806, -0.01418381743133068, -0.006235301494598389, -0.00976797565817833, 0.023732660338282585, 0.008280533365905285, 0.018314123153686523, -0.0025034171994775534, -0.02897854894399643, 0.027278615161776543, -0.00934299174696207, 0.01800866611301899, -0.03314869478344917, -0.010843714699149132, 0.013147920370101929, 0.021674146875739098, -0.014316624961793423, -0.006484315264970064, 0.014210378751158714, 0.03131595626473427, 0.02592398039996624, 0.010319125838577747, 0.015286117792129517, -0.00025212630862370133, 0.025658365339040756, 0.010578099638223648, 0.0004955371841788292, 0.011268697679042816, 0.010285923257470131, 0.013254166580736637, -0.016255611553788185, 0.016614191234111786, -0.006178858689963818, -0.006052691489458084, 0.016414979472756386, 0.008207489736378193, 0.030173813924193382, -0.010186318308115005, 0.0231084655970335, 0.02596382237970829, -0.0005636009154841304, -0.014130694791674614, 0.0038049286231398582, 0.006517517380416393, -0.029323846101760864, -0.006554039195179939, -0.019243774935603142, 0.016149364411830902, 0.006726688705384731, 0.02162102423608303, 0.01761024445295334, 0.0220327265560627, -0.0139 ...
