# %%
# !pip install purecpp_extract purecpp_chunks_clean
# Out:
# Requirement already satisfied: purecpp_extract in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: purecpp_chunks_clean in /usr/local/lib/python3.11/dist-packages (0.0.4)
# Requirement already satisfied: purecpp_libs in /usr/local/lib/python3.11/dist-packages (from purecpp_extract) (0.0.4)
# Requirement already satisfied: auditwheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (6.3.0)
# Requirement already satisfied: build in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (1.2.2.post1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (2.32.3)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (0.45.1)
# Requirement already satisfied: pybind11 in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (2.13.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from purecpp_chunks_clean) (75.2.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean) (24.2)
# Requirement already satisfied: pyelftools>=0.24 in /usr/local/lib/python3.11/dist-packages (from auditwheel->purecpp_chunks_clean) (0.32)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.11/dist-packages (from build->purecpp_chunks_clean) (1.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->purecpp_chunks_clean) (2025.1.31)

# %%
# !git clone https://github.com/PureAI-Tools/Tests.git # comentar isso no jupiter local
API_KEY = "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"
# Out:
# fatal: destination path 'Tests' already exists and is not an empty directory.

# %%
import purecpp_extract as ext
import purecpp_chunks_clean as cc
from purecpp_libs import DataExtractRequestStruct, LoaderDataStruct, RAGDocument

# %%
pdf_loader = ext.PDFLoader()
pdf_loader2 = ext.PDFLoader()
pdf_loader3 = ext.PDFLoader()

# %%
docxLoader = ext.DOCXLoader()
docxLoader2 = ext.DOCXLoader()

# %%
var = pdf_loader.InsertDataToExtract([
        DataExtractRequestStruct("Tests/pdfs/1984.pdf"),
        DataExtractRequestStruct("Tests/pdfs/a-christmas-carol.pdf"),
    ]) # No jupiter ta imprimindo q tao sendo achados arquivos aqui n
print(f"Content : \n {var}") # Poderia...
# Out:
# Content :
#  None

# %%
# pdf_loader2.InsertDataToExtract([DataExtractRequestStruct("pdfs")]) # deveria dar erro

# %%
pdf_loader3.InsertDataToExtract([DataExtractRequestStruct("pdfs/1984.pdf")])

# %%
docxLoader.InsertDataToExtract([
        DataExtractRequestStruct("Tests/docxs/sample1.docx"),
        DataExtractRequestStruct("Tests/docxs/sample4.docx")
    ]) # Tem que avisar que n encontra a pasta ou o arquivo na pasta se n o encontrar

# %%
docxLoader2.InsertDataToExtract([DataExtractRequestStruct("docxs")])

# %%
opt_struct = pdf_loader.GetTextContent("1984") # N retorna um tipo string
text_content = str(opt_struct)
text_content_limited = text_content[:100]
# print(text_content_limited)
for i in range(3):
  print(opt_struct.textContent[i:i+1])
  print("\n")

print(f"{len(opt_struct.textContent)} Pages")# Isso salva como paginas
# Out:
# ['Download free eBooks of classic literature, books and \r\nnovels at Planet eBook. Subscribe to our free eBooks blog \r\nand email newsletter.\r\n1984\r\nBy George Orwell']
#
#
# ['\x18 1984\r\nPart One']
#
#
# ['Free eBooks at Planet eBook.com \x18\r\nChapter 1\r\nI\r\nt was a bright cold day in April, and the clocks were strik\x02ing thirteen. Winston Smith, his chin nuzzled into his \r\nbreast in an effort to escape the vile wind, slipped quickly \r\nthrough the glass doors of Victory Mansions, though not \r\nquickly enough to prevent a swirl of gritty dust from enter\x02ing along with him.\r\nThe hallway smelt of boiled cabbage and old rag mats. At \r\none end of it a coloured poster, too large for indoor display, \r\nhad been tacked to the wall. It depicted simply an enor\x02mous face, more than a metre wide: the face of a man of \r\nabout forty-five, with a heavy black moustache and rugged\x02ly handsome features. Winston made for the stairs. It was \r\nno use trying the lift. Even at the best of times it was sel\x02dom working, and at present the electric current was cut \r\noff during daylight hours. It was part of the economy drive \r\nin preparation for Hate Week. The flat was seven flights up, \r\nand Winston, who was thirty-nine and had a varicose ulcer \r\nabove his right ankle, went slowly, resting several times on \r\nthe way. On each landing, opposite the lift-shaft, the poster \r\nwith the enormous face gazed from the wall. It was one of \r\nthose pictures which are so contrived that the eyes follow \r\nyou about when you move. BIG BROTHER IS WATCHING \r\nYOU, the caption beneath it ran.\r\nInside the flat a fruity voice was reading out a list of fig-']
#
#
# 393 Pages

# %%
print(type(opt_struct))
for item in dir(opt_struct):
    print(item)
print(type(dir(opt_struct)))
# help(opt_struct)
type(opt_struct.textContent)
# Out:
# <class 'purecpp_libs.purecpp_libs.LoaderDataStruct'>
# __class__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# _pybind11_conduit_v1_
# metadata
# textContent
# <class 'list'>
# list

# %%
for attr_name in dir(opt_struct):
    if not attr_name.startswith("__"):  # Ignora atributos internos
        try:
            value = getattr(opt_struct, attr_name)
            if attr_name == "textContent":
                print(f"{attr_name}: Is a list of {len(value)} Pages")
                print(f"Page 0 {attr_name} :\n{value[0]} ")
            else:
              print(f"{attr_name}: {value}")
            print("----------------------------------------------")
        except AttributeError:
            print(f"{attr_name}: [não acessível]")
# Out:
# _pybind11_conduit_v1_: <bound method PyCapsule._pybind11_conduit_v1_ of <purecpp_libs.purecpp_libs.LoaderDataStruct object at 0x78a749734df0>>
# ----------------------------------------------
# metadata: {'fileIdentifier': '1984'}
# ----------------------------------------------
# textContent: Is a list of 393 Pages
# Page 0 textContent :
# Download free eBooks of classic literature, books and
# novels at Planet eBook. Subscribe to our free eBooks blog
# and email newsletter.
# 1984
# By George Orwell
# ----------------------------------------------

# %%
pdf_loader.GetTextContent("1984")

# %%
if not pdf_loader3.GetTextContent("a-christmas-carol"): # DEVERIA DAR ERRO
    print("deu erro")
# Out:
# deu erro

# %%
pdf_loader3.GetTextContent("sdauhdsahudsauhdsahuds") # DEVERIA DAR ERRO

# %%
# print(type(pdf_loader))
# for item in dir(pdf_loader):
#     print(item)
# print(type(dir(pdf_loader)))

# %%
# help(pdf_loader)

# %%
items_docx = []

for fname in ["sample1", "sample4"]: # poderia ter um metodo para recuperar as listas naquela List de LoaderDataStruct < --------------- >
    x = docxLoader.GetTextContent(fname)
    if x:
        items_docx.append(x.textContent)  # cada item é um List em LoaderDataStruct
    else:
        print(f"Não foi possível extrair: {fname}")
if not items_docx:
        print("Nenhum documento foi carregado com sucesso! Encerrando.")
print(f"Total de documentos carregados: {len(items_docx)}\n")
# Out:
# Total de documentos carregados: 2

# %%
items = []
item_struct =  []

for fname in ["1984", "a-christmas-carol"]: # poderia ter um metodo para recuperar as listas naquela List de LoaderDataStruct < --------------- >
    opt_struct = pdf_loader.GetTextContent(fname)
    if opt_struct:
        items.append(opt_struct.textContent)   # cada item é um List em LoaderDataStruct
        item_struct.append(opt_struct) # cada item é LoaderDataStruct
    else:
        print(f"Não foi possível extrair: {fname}")
if not items:
        print("Nenhum documento foi carregado com sucesso! Encerrando.")
print(f"Total de documentos carregados: {len(items)}\n")
# Out:
# Total de documentos carregados: 2

# %%
print("---------------------------------------------------------")
for i, lds in enumerate(item_struct):
    print(f"--- LoaderDataStruct nº {i} ---")

    print(">> METADATA:")
    for mk, mv in lds.metadata.items():
        print(f"   {mk} => {mv}")

    print(f"\n>> TEXT CONTENT=> {lds.textContent[10][:100]} ...")
    print()
print("---------------------------------------------------------")
# Out:
# ---------------------------------------------------------
# --- LoaderDataStruct nº 0 ---
# >> METADATA:
#    fileIdentifier => 1984
#
# >> TEXT CONTENT=> Free eBooks at Planet eBook.com 11
# er of expressing himself, but even to have forgotten what it
# w ...
#
# --- LoaderDataStruct nº 1 ---
# >> METADATA:
#    fileIdentifier => a-christmas-carol
#
# >> TEXT CONTENT=> Free eBooks at Planet eBook.com 11
# ‘Under the impression that they scarcely furnish Christian chee ...
#
# ---------------------------------------------------------

# %%
# 2) CHUNKANDO COM ChunkDefault
#    (divide texto em blocos de 300 chars, com overlap=50)
# default_chunker = cc.ChunkDefault(chunk_size=300, overlap=50)
chunk_size=1000
overlap=200
default_chunker = cc.ChunkDefault(chunk_size, overlap) # poderia passar o item ja aqui
default_chunker2 = cc.ChunkDefault(chunk_size, overlap)

# %%
# std::vector<RAGLibrary::Document> ProcessSingleDocument(RAGLibrary::LoaderDataStruct &item);
default_docs = default_chunker.ProcessData(item_struct[0])
# std::vector<RAGLibrary::Document> ProcessDocuments(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
default_docs2 = default_chunker2.ProcessData(item_struct, max_workers=2) # Tem q ser uma lista de purecpp_libs.purecpp_libs.LoaderDataStruct

# %%
print(f"ChunkDefault({chunk_size}, {overlap}) from  documents.size={len(default_docs)}")
print(f"ChunkDefault({chunk_size}, {overlap}) from  documents.size={len(default_docs2)}")
# Out:
# ChunkDefault(1000, 200) from  documents.size=775
# ChunkDefault(1000, 200) from  documents.size=982

# %%
# print(type(default_docs[0])) # purecpp_libs.purecpp_libs.RAGDocument
# for item in dir(default_docs[0]):
#     print(item)

# %%
# default_docs[0]
# help(default_docs)

# %%
print("-----------------------------------------------------------------------------------------")
print("default")
list_default_docs = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs)
first_n = default_docs[:3]            # primeiros 3
last_n = default_docs[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs.append(doc.page_content)

print("-----------------------------------------------------------------------------------------")
print("default 2")
list_default_docs2 = []
# Garantir que temos ao menos 3 elementos
n = len(default_docs2)
first_n = default_docs2[:3]            # primeiros 3
last_n = default_docs2[-3:] if n >= 3 else []  # últimos 3 (sem repetir os primeiros)
# Adiciona os page_content dos primeiros
for i, doc in enumerate(first_n):
    print(f"Primeiro [{i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
# Adiciona os page_content dos últimos
for i, doc in enumerate(last_n):
    print(f"Último [{n - 3 + i}] METADATA =>", doc.metadata)
    list_default_docs2.append(doc.page_content)
print("-----------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------
# default
# Primeiro [0] METADATA => {'fileIdentifier': '1984'}
# Primeiro [1] METADATA => {'fileIdentifier': '1984'}
# Primeiro [2] METADATA => {'fileIdentifier': '1984'}
# Último [772] METADATA => {'fileIdentifier': '1984'}
# Último [773] METADATA => {'fileIdentifier': '1984'}
# Último [774] METADATA => {'fileIdentifier': '1984'}
# -----------------------------------------------------------------------------------------
# default 2
# Primeiro [0] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Primeiro [1] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Primeiro [2] METADATA => {'fileIdentifier': 'a-christmas-carol'}
# Último [979] METADATA => {'fileIdentifier': '1984'}
# Último [980] METADATA => {'fileIdentifier': '1984'}
# Último [981] METADATA => {'fileIdentifier': '1984'}
# -----------------------------------------------------------------------------------------

# %%
# Corrija a função len caso tenha sido sobrescrita em alguma célula anterior
try:
    del len  # remove variável len, se existir
except:
    pass  # ignora erro caso len ainda seja a função original

# Processando os documentos da primeira lista
for i, doc in enumerate(list_default_docs):
    print(f"Chunk begin{i}:  \"{doc[:50]} ...\" ")
    doc_length = len(doc)
    diff_index = doc_length - 50
    print(f"Chunk {i}:  \"{doc[diff_index:]} ...\" ")
    print("Length Chunk ", doc_length)
    print("______________________________")

print("-" * 90)

# Processando os documentos da segunda lista
for i, doc in enumerate(list_default_docs2):
    print(f"Chunk begin {i}:  \"{doc[:50]} ...\" ")
    doc_length = len(doc)
    diff_index = doc_length - 50
    print(f"Chunk {i}:  \"{doc[diff_index:]} ...\" ")
    print("Length Chunk ", doc_length)
    print("______________________________")
# Out:
# Chunk begin0:  "Download free eBooks of classic literature, books  ..."
# Chunk 0:  "es it was seldom working, and at present the elec ..."
# Length Chunk  1000
# ______________________________
# Chunk begin1:  "e, with a heavy black moustache and ruggedly hand ..."
# Chunk 1:  "med part of the surface of the
# right-hand wall.  ..."
# Length Chunk  1000
# ______________________________
# Chunk begin2:  "g-
# 1984
# ures which had something to do with the p ..."
# Chunk 2:  " a harsh blue, there seemed
# to be no colour in a ..."
# Length Chunk  1000
# ______________________________
# Chunk begin3:  "as well as language. Take for example
# the well-k ..."
# Chunk 3:  "uld be changed into a panegyric on
# absolute gove ..."
# Length Chunk  998
# ______________________________
# Chunk begin4:  "w the
# whole passage up in the single word CRIMET ..."
# Chunk 4:  "here were also large quantities of
# merely utilit ..."
# Length Chunk  998
# ______________________________
# Chunk begin5:  " slow and difficult business, and it was not expec ..."
# Chunk 5:  "speak had been
# fixed for so late a date as 2050. ..."
# Length Chunk  504
# ______________________________
# ------------------------------------------------------------------------------------------
# Chunk begin 0:  "Download free eBooks of classic literature, books  ..."
# Chunk 0:  "w, of my own knowledge, what there is particularl ..."
# Length Chunk  992
# ______________________________
# Chunk begin 1:  "e was good
# upon ‘Change, for anything he chose t ..."
# Chunk 1:  "siness on the very day of the funeral,
# and solem ..."
# Length Chunk  992
# ______________________________
# Chunk begin 2:  "gatee,
# his sole friend, and sole mourner. And ev ..."
# Chunk 2:  "t
# stood, years afterwards, above the warehouse d ..."
# Length Chunk  986
# ______________________________
# Chunk begin 3:  "as well as language. Take for example
# the well-k ..."
# Chunk 3:  "uld be changed into a panegyric on
# absolute gove ..."
# Length Chunk  998
# ______________________________
# Chunk begin 4:  "w the
# whole passage up in the single word CRIMET ..."
# Chunk 4:  "here were also large quantities of
# merely utilit ..."
# Length Chunk  998
# ______________________________
# Chunk begin 5:  " slow and difficult business, and it was not expec ..."
# Chunk 5:  "speak had been
# fixed for so late a date as 2050. ..."
# Length Chunk  504
# ______________________________

# %%
def find_overlap(a: str, b: str) -> int:
    """
    Retorna o número de caracteres de overlap entre o final de 'a' e o início de 'b'.
    Exemplo:
    a = "ABCDEFG", b = "EFGHIJ" → overlap = 3 ("EFG")
    """
    max_overlap = min(len(a), len(b))
    for i in range(max_overlap, 0, -1):
        if a[-i:] == b[:i]:
            return i
    return 0

# Verifica overlaps entre docs consecutivos
for i in range(len(list_default_docs) - 1):
    a = list_default_docs[i]
    b = list_default_docs[i + 1]
    overlap = find_overlap(a, b)

    if overlap > 0:
        print(f"✅ Overlap entre doc[{i}] e doc[{i+1}]: {overlap} caracteres")
        print(f"Trecho comum: \"{a[-overlap:]}\"")
    else:
        print(f"❌ Sem overlap entre doc[{i}] e doc[{i+1}]")

    print("─────────────────────────────")
# Out:
# ✅ Overlap entre doc[0] e doc[1]: 200 caracteres
# Trecho comum: "e, with a heavy black moustache and ruggedly handsome features. Winston made for the stairs. It was
# no use trying the lift. Even at the best of times it was seldom working, and at present the elec"
# ─────────────────────────────
# ✅ Overlap entre doc[1] e doc[2]: 200 caracteres
# Trecho comum: "g-
# 1984
# ures which had something to do with the production of
# pig-iron. The voice came from an oblong metal plaque like
# a dulled mirror which formed part of the surface of the
# right-hand wall. "
# ─────────────────────────────
# ✅ Overlap entre doc[2] e doc[3]: 1 caracteres
# Trecho comum: "a"
# ─────────────────────────────
# ✅ Overlap entre doc[3] e doc[4]: 198 caracteres
# Trecho comum: "w the
# whole passage up in the single word CRIMETHINK. A full
# translation could only be an ideological translation, whereby Jefferson’s words would be changed into a panegyric on
# absolute gove"
# ─────────────────────────────
# ✅ Overlap entre doc[4] e doc[5]: 200 caracteres
# Trecho comum: " slow and difficult business, and it was not expected that
# they would be finished before the first or second decade of
# the twenty-first century. There were also large quantities of
# merely utilit"
# ─────────────────────────────

# %%
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_default_docs,
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])}")
    print(type(openai_emb))
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    # (c) Normalizar a primeira embedding
    print("\n\n\n")
    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
# Out:
# [EmbeddingOpeanAI] Embedding gerada com dim=1536
# <class 'list'>
# 0:
# <class 'list'>
# [-0.004259486682713032, -0.022561969235539436, -0.031041009351611137, -0.02477157860994339, 0.01811612956225872, 0.01401637401431799, -0.02003289945423603, -0.002462515840306878, -0.01751714013516903, -0.03080141358077526, 0.012159503996372223, 0.03958660364151001, -0.025317324325442314, 0.015254287049174309, 0.016944771632552147, 0.02978978492319584, 0.02869829162955284, -0.006013197358697653, 0.008911645039916039, -0.00967036560177803, -0.0006730321911163628, 0.018794985488057137, 0.0016705174930393696, -0.024811509996652603, -0.012958157807588577, -0.03636536747217178, 0.02891126647591591, -0.04451163858175278, 0.031946152448654175, -0.027606798335909843, -0.0011946529848501086, -0.014575431123375893, -0.018568700179457664, -0.014681918546557426, -0.015853276476264, -0.006419179495424032, -0.002828565426170826, -0.0020581972785294056, 0.02276163175702095, -0.015001379884779453, 0.02285480871796608, 0.019314110279083252, -0.0019750043284147978, 0.007680387236177921, -0.03540698438882828, 0.033011022955179214, 0.012265990488231182, -0.03223899006843567, 0.002623910317197442, 0.0010415776632726192, 0.010402465239167213, 0.023121027275919914, 0.01691814884543419, -0.024917997419834137, -0.005001569166779518, 0.004512393847107887, 0.011560513637959957, 0.013057989068329334, -0.0060464744456112385, -0.018528766930103302, 0.00990330707281828, -0.003291119122877717, -0.03604590520262718, -0.03322399780154228, -0.018382348120212555, 0.0024641796480864286, -0.022082775831222534, 0.005477433558553457, -0.019101135432720184, -0.007301026489585638, 0.05215208977460861, 0.010142902843654156, -0.016505511477589607, 0.021244190633296967, 0.007221161387860775, -0.005756962578743696, -0.020166007801890373, -0.00324619491584599, -0.003833538154140115, -0.0014625347685068846, 0.004016562830656767, -0.007647109683603048, 0.010755203664302826, 0.0062161884270608425, -0.006369263865053654, 0.01670517399907112, 0.0002707935345824808, 0.016851594671607018, -0.041902702301740646, -0.017344098538160324, -0.012538864277303219, -0.01053557451814413, 0.007580555509775877, 0.010182835161685944, -0.02909761853516102, 0.009097997099161148, -0.011820076033473015, 0.025091039016842842, 0.005543988198041916, -0.026289019733667374, 0.024571914225816727, -0.016372403129935265, -0.01304467860609293, -0.001675509032793343, -0.015427328646183014, 0.02941708080470562, 0.02728733792901039, -0.005131350364536047, 0.022269129753112793, -0.005008224863559008, -0.008159579709172249, 0.014255969785153866, 0.01032925583422184, -0.0323454774916172, 0.026954565197229385, -0.029683297500014305, 0.002687137108296156, -0.01864856481552124, -0.02668834663927555, -0.018129440024495125, -0.02310771495103836, 0.034049272537231445, 0.03325061872601509, 0.0031580100767314434, 0.00946404691785574, -0.023600218817591667, -0.039293766021728516, 0.0036738072521984577, -0.02978978492319584, -0.0076870424672961235, 0.033516835421323776, 0.023027850314974785, 0.031253982335329056, -0.001192157156765461, -0.01792977750301361, 0.031200740486383438, -0.022974606603384018, 0.003424227936193347, -0.011899941600859165, 0.0017903154948726296, 0.0251176618039608, 0.03428886830806732, 0.008385865017771721, -0.003099774941802025, -0.020778309553861618, 0.025130972266197205, 0.008212822489440441, 0.017503827810287476, 0.004578948486596346, 0.002044886350631714, 0.004895082209259272, -0.0049915858544409275, -0.009370870888233185, -0.007713664323091507, 0.007766908034682274, 0.01830248162150383, -0.005454139783978462, 0.03383629769086838, -0.011201119050383568, -0.009530602023005486, 0.022561969235539436, 0.021869802847504616, 0.024665091186761856, -0.010209457017481327, 0.020578645169734955, 0.02147047594189644, 0.023959612473845482, 0.008924955502152443, 0.006269432138651609, 0.0006389230256900191, -0.03157344460487366, 0.01730416528880596, -0.016345780342817307, 0.00857221707701683, 0.04259486868977547, 0.051220327615737915, 0.002252869075164199, 0.024811509996652603, 0.002885136753320694, -0.012958 ...
# 1:
# <class 'list'>
# [-0.021177854388952255, -0.02119181491434574, -0.0024081608280539513, -0.01467233058065176, -0.001346301520243287, 0.007566511165350676, -0.0068126521073281765, -0.027278529480099678, -0.024109529331326485, -0.025407841429114342, 0.0008018477237783372, 0.025365959852933884, -0.023690717294812202, -0.014825894497334957, 0.001161326770670712, 0.013890550471842289, 0.027194766327738762, 0.020689241588115692, 0.007608392275869846, -0.02272745408117771, -0.006554385647177696, 0.008494874462485313, -0.014784012921154499, -0.020423995330929756, -0.010170117020606995, -0.013967332430183887, 0.02505883201956749, -0.02329982817173004, -0.0070918588899075985, -0.0020766023080796003, 0.00882992334663868, -0.024975070729851723, -0.017115391790866852, -0.00570280384272337, -0.038837701082229614, -0.024584179744124413, -0.009639623574912548, -0.015817079693078995, 0.025351999327540398, -0.007852698676288128, 0.019209444522857666, 0.005612061824649572, -0.013360057026147842, 0.007741015404462814, -0.04107135534286499, 0.019363008439540863, 0.00834829080849886, -0.0160125233232975, -7.40553077775985e-05, 0.0288141667842865, 0.008620517328381538, 0.01759004406630993, 0.0028374416287988424, -0.02430497296154499, -0.0036645925138145685, -0.003060807241126895, 0.02801842801272869, 0.014937576837837696, 0.0016569193685427308, -0.006051812786608934, 0.006491563748568296, -0.016319651156663895, -0.037720873951911926, -0.011691794730722904, -0.011684815399348736, 0.011559171602129936, -0.012215307913720608, -0.00997467152774334, -0.01573331654071808, -0.0008795022149570286, 0.034398309886455536, 0.014435004442930222, -0.014839855022728443, -0.0023680247832089663, 0.022462207823991776, -0.0032108810264617205, -0.00972338579595089, -0.008055123500525951, -0.0033312891609966755, 0.006156515330076218, 0.013380997814238071, -0.016235889866948128, -0.014881735667586327, 0.023439431563019753, 0.020759044215083122, 0.013164612464606762, -0.01440708339214325, 0.019418850541114807, -0.02391408383846283, -0.004118303768336773, -0.014476885087788105, 0.0065648555755615234, -0.0075385901145637035, 0.0069382949732244015, -0.002458767034113407, 0.019670136272907257, -0.011691794730722904, 0.01915360428392887, 0.006037852261215448, -0.02402576617896557, 0.01590084098279476, -0.013709066435694695, -0.026105858385562897, -0.00040114199509844184, -0.005018746480345726, 0.010512145236134529, -0.008397151716053486, -0.008320369757711887, 0.023397549986839294, -0.020144788548350334, -2.8166101401438937e-05, 0.038335125893354416, 0.020382113754749298, -0.03110366500914097, 0.030405648052692413, -0.035152167081832886, 0.00419159559533, -0.018008854240179062, -0.009856008924543858, -0.004292808473110199, -0.01619400829076767, 0.015063220635056496, 0.042299866676330566, 0.000173522814293392, 0.016961827874183655, -0.01183139905333519, -0.030768616124987602, -0.002102778060361743, -0.015160942450165749, -0.004205556120723486, 0.032471779733896255, 0.003580830292776227, 0.022755375131964684, -0.012194368056952953, 0.0030468469485640526, 0.010211997665464878, -0.018595188856124878, 0.007922500371932983, -0.014253519475460052, -0.020996369421482086, 0.008103984408080578, 0.010037492960691452, -0.012829563580453396, -0.0054689678363502026, -0.010142195969820023, 0.009911850094795227, -0.008264528587460518, 0.01367416512221098, 0.002612330950796604, -0.01651509664952755, -0.007601412013173103, -0.017282916232943535, -0.0011473664781078696, -0.004177635535597801, 0.004306768532842398, 0.017966972663998604, -0.004826792050153017, 0.010302740149199963, -0.03518008813261986, 0.02034023404121399, -0.0010452814167365432, 0.01240377314388752, 0.019209444522857666, -0.0034761277493089437, 0.01492361631244421, 0.02537992037832737, 0.017785489559173584, -0.00956284161657095, 0.004156694747507572, 0.005535279866307974, -0.00028313338407315314, 0.0036401618272066116, -0.022671611979603767, 0.029428422451019287, 0.026105858385562897, 0.034370388835668564, 0.0011796497274190187, 0.007329185027629 ...
# 2:
# <class 'list'>
# [-0.02067345194518566, -0.02063160389661789, 0.0003570250701159239, -0.019975967705249786, -0.005527567584067583, 0.006239002570509911, -0.019348230212926865, -0.022975152358412743, -0.04832175374031067, -0.016544342041015625, 0.007379390299320221, 0.050163112580776215, -0.009220750071108341, 0.0010967949638143182, -0.006556358188390732, 0.015986353158950806, 0.013273137621581554, 0.022249767556786537, 0.024732815101742744, -0.03166581317782402, -0.01229665894061327, -0.001965163741260767, 0.000868368661031127, -0.013580030761659145, -0.011173708364367485, -0.0044534411281347275, 0.03939394652843475, -0.02887587435543537, 0.0014516403898596764, 0.017911411821842194, 0.011543374508619308, -0.02091059647500515, -0.023616839200258255, -0.014354239217936993, -0.018832091242074966, 0.007093421183526516, 0.00032912567257881165, -0.0097578139975667, 0.015581812709569931, -0.018232254311442375, 0.013545156456530094, 0.02266825921833515, 0.0014193817041814327, 0.003182274755090475, -0.018594946712255478, 0.033451374620199203, -0.0017036068020388484, 0.010050756856799126, -0.022835655137896538, 0.0187065452337265, 0.018162505701184273, 0.029545459896326065, -0.006615644320845604, -0.003919865004718304, -0.001387123134918511, -0.004990504588931799, 0.012024639174342155, 0.026769470423460007, 0.0006294801132753491, -0.021956823766231537, -0.0013391709653660655, -0.011836318299174309, -0.026169633492827415, -0.025527946650981903, -0.019683023914694786, 0.008320994675159454, -0.015233069658279419, -0.0019320331048220396, -0.021956823766231537, 0.017353424802422523, 0.04229548200964928, 0.013872974552214146, -0.007246868219226599, 0.0022947252728044987, 0.02661602385342121, -0.00551710557192564, -0.01612585037946701, -0.01609795168042183, -0.011445727199316025, 0.011557324789464474, 0.015079623088240623, -0.023058850318193436, -0.02208237163722515, -0.0023243683390319347, 0.008167548105120659, 0.010113530792295933, 3.111436672043055e-05, 0.029517561197280884, -0.001430715899914503, -0.018176456913352013, -0.004704535473138094, 0.01666988804936409, 0.01330103725194931, 0.014214741997420788, -0.00029403346707113087, 0.02738325670361519, -0.007117833476513624, 0.03133102133870125, -0.008955705910921097, -0.035711225122213364, -0.004338356200605631, 0.006681905128061771, -0.0141240693628788, -0.00529739772900939, -0.018036959692835808, 0.01747897081077099, -0.005911184474825859, -0.0007105627446435392, 0.022445064038038254, -0.03649241104722023, -0.017953261733055115, 0.028457382693886757, 0.021859176456928253, -0.02940596267580986, 0.021635981276631355, -0.026058034971356392, 0.014800629578530788, -0.0011220788583159447, -0.027536703273653984, -0.021998673677444458, -0.03250279650092125, 0.015372566878795624, 0.014026421122252941, -0.004223270807415247, 0.03166581317782402, -0.003077652072533965, -0.027006614953279495, -0.014451886527240276, -0.01866469532251358, -0.010929588228464127, 0.03702249750494957, 0.0062913135625422, 0.017757965251803398, -0.011396903544664383, -0.005171850323677063, 0.02798309363424778, -0.02993605099618435, 0.025053657591342926, -0.0039721764624118805, -0.023937681689858437, 0.009583442471921444, 0.01813460700213909, -0.009764788672327995, -0.015456264838576317, -0.013077842071652412, 0.029545459896326065, -0.016321146860718727, 0.014019446447491646, 0.008830158971250057, 0.0022214893251657486, 0.008432592265307903, -0.03978453949093819, 0.006451735273003578, -0.02460726723074913, 0.01185724325478077, 0.015512064099311829, 0.0065703075379133224, 0.038891758769750595, -0.02403532899916172, 0.015567862428724766, -0.0025632570032030344, 0.006587744690477848, 0.03222380205988884, -0.0004633915377780795, 0.005747275426983833, 0.02543029934167862, 0.021315138787031174, 0.013510282151401043, 0.0003892837557941675, 0.007093421183526516, -0.011062110774219036, 0.02767620049417019, -0.024411970749497414, 0.008948731236159801, 0.01147362682968378, 0.026992665603756905, 0.02287750504910946, 0.021622031927108765, -0.0075467866845 ...
# 3:
# <class 'list'>
# [0.004705816973000765, 0.00563627015799284, -0.015422762371599674, -0.016105541959404945, -0.016587503254413605, 0.01062323059886694, -0.010181433521211147, -0.008528037928044796, -0.017939671874046326, -0.02142050303518772, 0.014833698980510235, 0.022049730643630028, -0.008240199647843838, -0.00721603212878108, 0.007082154043018818, 0.024713905528187752, 0.036548733711242676, -0.00787872914224863, 0.002868339419364929, -0.016306357458233833, -0.006549988407641649, 0.00865522213280201, 0.009217510931193829, 0.004662306513637304, -0.004950144328176975, -0.0013889857800677419, 0.03089907579123974, -0.03263949230313301, 0.0015094761038199067, -0.013407896272838116, 0.01051612850278616, -0.002274255035445094, -0.02174181118607521, -0.012972792610526085, -0.023910637944936752, -0.012343565002083778, -0.026293668895959854, -0.01084413006901741, 0.00755072757601738, -0.016252806410193443, 0.021072421222925186, -0.012363647110760212, 0.00721603212878108, -0.020054945722222328, -0.008574895560741425, 0.022518305107951164, 0.014070593751966953, -0.030015481635928154, -0.018327917903661728, 0.017243504524230957, 0.044313665479421616, 0.043724603950977325, -0.047446414828300476, -0.01791289635002613, -0.016533950343728065, -0.004133487585932016, 0.0012609647819772363, 0.024178393185138702, 0.00270266504958272, -0.0015094761038199067, 0.025744767859578133, 0.0027796451468020678, -0.002948666224256158, 0.02282622456550598, -0.00782517809420824, -0.014030429534614086, -0.027364693582057953, 0.00879579409956932, 0.0006158394971862435, 0.0007559931837022305, 0.0372181236743927, 0.020108498632907867, 0.008320527151226997, -0.005023777484893799, 0.03365696594119072, -0.009003305807709694, -0.017029300332069397, -0.023107368499040604, -0.00769799342378974, 0.012095890939235687, 0.012966098263859749, -0.004274060018360615, -0.01789950765669346, 0.000994881964288652, 0.005997741129249334, -0.017230117693543434, -0.014994352124631405, 0.034379906952381134, 0.02362949214875698, -0.027766328305006027, -0.011533602140843868, 0.0013697408139705658, -0.013735897839069366, 0.02104564569890499, -0.023763371631503105, 0.010957926511764526, -0.007718075066804886, 0.016681216657161713, 0.0056797806173563, -0.024017740041017532, 0.02022898755967617, 0.015382599085569382, -0.033469535410404205, -0.007778320461511612, -0.005134226754307747, -0.00496353255584836, -0.0013563529355451465, 0.01496757660061121, -0.007979137822985649, -0.008695385418832302, -0.000863514025695622, 0.02049674466252327, 0.017216729000210762, -0.04297488555312157, 0.01672138087451458, -0.01866261288523674, -0.012564464472234249, -0.023160919547080994, -0.01510145515203476, -0.03494219481945038, -0.01408398151397705, 0.014713208191096783, 0.015088067390024662, 0.006208599079400301, 0.031247159466147423, 0.010362168774008751, -0.006462967488914728, 0.002547031734138727, -0.011393030174076557, -0.00434434600174427, 0.026039300486445427, 0.004120099823921919, 0.018916983157396317, -0.009217510931193829, -0.010268453508615494, 0.03205042704939842, -0.00863514095544815, 0.025851869955658913, 0.012557770125567913, -0.025918809697031975, 0.037244901061058044, 0.009726247750222683, 0.007959055714309216, 0.0026524607092142105, 0.021969404071569443, 0.014512390829622746, -0.0012693321332335472, 0.011767889373004436, -0.00283989030867815, 0.010315311141312122, 0.010830742307007313, 0.00990028865635395, 0.006981745362281799, -0.002178866881877184, 0.007450318895280361, 0.012524300254881382, -0.009866819716989994, 0.02562427707016468, 0.016707992181181908, 0.012236462906002998, 0.0019127840641885996, -0.007323134690523148, 0.003425606992095709, 0.0005530840717256069, 0.008675304241478443, 0.033201780170202255, 0.023000266402959824, 0.02270573377609253, 0.0024884601589292288, -0.0033101371955126524, -0.006429498083889484, 0.0451972633600235, -0.01467304490506649, 0.023160919547080994, 0.0018173959106206894, 0.013180303387343884, 0.018809879198670387, 0.033094678074121475, -0.011299315840005875, -0.01127 ...
# 4:
# <class 'list'>
# [0.006384111009538174, -0.0042228056117892265, 0.0026345213409513235, -0.006329045630991459, 0.00198578555136919, 0.022466564550995827, -0.01592758297920227, -0.011336528696119785, -0.013862640596926212, -0.02074578031897545, 0.03312166407704353, 0.039426617324352264, -0.02450397238135338, -0.0024194230791181326, 0.005520277190953493, 0.01899746246635914, 0.04275805503129959, 0.0038270249497145414, -0.010159512050449848, -0.025784237310290337, -0.009815355762839317, 0.003861440811306238, -0.008555741049349308, -0.0036859207320958376, -0.013373938389122486, -0.00601586326956749, 0.03540686517953873, -0.04873261973261833, -0.00708963256329298, -0.012066141702234745, -0.0042813122272491455, -0.00038158398820087314, -0.006855606101453304, -0.008652104996144772, -0.027436189353466034, -0.029680093750357628, -0.014206797815859318, -0.0013241437263786793, 0.006201707758009434, -0.006222357042133808, 0.006132876500487328, 0.011074969545006752, 0.01632680371403694, -0.02041538804769516, 0.0026482874527573586, 0.011219515465199947, 0.009973667562007904, -0.02945983223617077, -0.01044172141700983, 0.0018343564588576555, 0.04592429846525192, 0.054046403616666794, -0.02435254491865635, -0.02912944182753563, -0.022920850664377213, -0.018433045595884323, -0.005430796183645725, 0.02729852683842182, 0.006883138325065374, 0.006298071704804897, 0.03281880542635918, 0.004009427968412638, -0.01375939417630434, 0.007963791489601135, 0.005454887170344591, -0.015693556517362595, -0.03372737765312195, 0.008624572306871414, 0.00876911822706461, -0.00725482776761055, 0.027697749435901642, 0.022397732362151146, -0.003603322897106409, 0.0046805343590676785, 0.03565465658903122, -0.0005386056145653129, -0.012279518879950047, -0.008961846120655537, -0.011343412101268768, 0.0109028909355402, 0.017799796536564827, -0.011508607305586338, -0.008445611223578453, 0.006669761147350073, 0.0005631267558783293, -0.016381869092583656, -0.006239565089344978, 0.027449956163764, 0.00731677608564496, -0.01855694130063057, -0.008094570599496365, 0.005867875646799803, 0.001485897577367723, 0.018088888376951218, -0.016244206577539444, 0.0037581936921924353, -0.009519380517303944, 0.0165470652282238, -0.0015736575005576015, -0.020663181319832802, 0.03218555450439453, 0.010510552674531937, -0.028991779312491417, -0.008266649208962917, -0.012885235249996185, -0.0006358299287967384, -0.013718094676733017, 0.012678741477429867, 0.005981447175145149, -0.02165435440838337, -0.008080804720520973, 0.022796954959630966, 0.013353289104998112, -0.03485621511936188, 0.022975916042923927, -0.01990603655576706, 0.0073511917144060135, -0.014922644011676311, 0.0020391298457980156, -0.02504085749387741, -0.013945238664746284, 0.003926830366253853, 0.015500827692449093, -0.0009429899509996176, 0.028716454282402992, 0.021847082301974297, -0.008658988401293755, 0.0022490655537694693, -0.024008387699723244, -0.0013783484464511275, 0.007922491990029812, -0.01417926512658596, 0.010751462541520596, -0.015005242079496384, -0.0038958564400672913, 0.0341954305768013, -0.013084846548736095, 0.019369151443243027, 0.008094570599496365, -0.03747180476784706, 0.022039810195565224, 0.026596447452902794, 0.002588059986010194, 0.01461978629231453, -0.006803982425481081, 0.02926710434257984, -0.011006138287484646, 0.03251594677567482, 0.010056265629827976, -0.010531201958656311, 0.0027876710519194603, -0.010228344239294529, 0.018969928845763206, 0.004308844916522503, 0.0014308324316516519, 0.025027090683579445, -0.0010901170317083597, 0.014316927641630173, -0.0015882841544225812, -0.005420471541583538, 0.0021337729413062334, -0.014206797815859318, -0.0008341503562405705, -0.0017586419126018882, 0.018680837005376816, 0.04028012603521347, 0.021695652976632118, 0.02256292849779129, 0.017703432589769363, -0.021695652976632118, -0.00604339549317956, 0.011928479187190533, -0.042124807834625244, 0.02817956916987896, -0.0031490358524024487, 0.01380069274455309, 0.003696245374158025, 0.027945542708039284, -0.00943678244 ...
# 5:
# <class 'list'>
# [-0.007222527638077736, -0.028613118454813957, -0.007873455062508583, -0.009563096798956394, 0.023599591106176376, 0.006858977489173412, -0.03351585194468498, -0.0007322936435230076, -0.033986736088991165, -0.04068990424275398, 0.022713221609592438, 0.034651514142751694, -0.007949627935886383, 0.0034346822649240494, 0.003497005207464099, 0.012007538229227066, 0.02287941612303257, -0.004920043982565403, -0.006041855551302433, -0.02062194235622883, 0.009743141010403633, 0.004881957545876503, -0.012997779995203018, -0.01375950314104557, -0.02131441980600357, -0.015206778421998024, 0.018586063757538795, -0.04016362503170967, -0.02631409838795662, -0.004663827829062939, 0.0025483127683401108, -0.024846049025654793, 0.0013555223122239113, -0.011058845557272434, -0.028807012364268303, -0.03005347028374672, -0.0009971658000722528, -0.01008937880396843, 0.01733960583806038, -0.04498325660824776, 0.027242016047239304, 0.009819313883781433, 0.006640847306698561, -0.004774624016135931, -0.04836254194378853, 0.008545157499611378, 0.032712578773498535, 0.0004176497459411621, 0.006360394414514303, 0.002925712149590254, 0.011121168732643127, 0.0244582612067461, -0.001275887480005622, -0.021632958203554153, -0.001636840752325952, -0.001194521551951766, -0.00409253453835845, 0.016273193061351776, -0.0023959679529070854, -0.018184427171945572, 0.0066546970047056675, -0.0032788750249892473, -0.015649963170289993, 0.009853937663137913, -0.007229452021420002, -0.017464252188801765, -0.01740885339677334, -0.004345288500189781, -0.008496684022247791, -0.014361958019435406, 0.0032130898907780647, 0.0018662235233932734, 0.019569380208849907, 0.0218268521130085, 0.021591410040855408, 0.015303725376725197, 0.018724558874964714, -0.020386502146720886, -0.010830328799784184, 0.0036458875983953476, 0.006706632673740387, -0.022020746022462845, -0.0014368882402777672, 0.014375807717442513, 0.008926019072532654, -0.016397837549448013, -0.0019441271433606744, 0.011917516589164734, -0.0240012276917696, -0.01498518604785204, 0.001522582140751183, -0.0005894704372622073, -0.00524896988645196, 0.03362664580345154, -0.012859283946454525, -0.004646515939384699, -0.013392491266131401, 0.01577460952103138, -0.019112344831228256, -0.025995559990406036, -0.002087815897539258, -0.004213718231767416, -0.016051599755883217, -0.0031247991137206554, -0.02386273257434368, 0.0283499788492918, 0.015885405242443085, 0.030164266005158424, 0.01084417849779129, -0.01046331599354744, -0.014749744907021523, 0.024485960602760315, 0.0003832423244602978, -0.008655953221023083, 0.01675792597234249, -0.034263726323843, 0.0076310886070132256, -0.002479064976796508, 0.01891845092177391, -0.02684037946164608, 0.013994945213198662, 0.0028616581112146378, 0.036230359226465225, -0.014320408925414085, 0.01847526617348194, 0.0019354711985215545, -0.01559456530958414, -0.001714744372293353, -0.01937548629939556, -0.0196524765342474, -0.01621779426932335, 0.009286106564104557, 0.028751615434885025, 0.00372898462228477, 0.007998100481927395, 0.037559911608695984, -0.007831906899809837, 0.0033446603920310736, -0.015954652801156044, -0.02423666976392269, 0.024873748421669006, 0.03850167989730835, -0.026341797783970833, 0.004881957545876503, 0.0003339033864904195, 0.014251161366701126, -0.007395646534860134, 0.007638013456016779, 0.023904280737042427, -0.006062629632651806, 0.0072571514174342155, -0.009424601681530476, -0.00848975870758295, 0.003310036612674594, -0.005338991992175579, 0.00639155600219965, 0.017588896676898003, 0.03124452941119671, -0.004833484534174204, 0.0040405988693237305, 0.009597721509635448, -0.0003330378094688058, 0.02639719471335411, -0.01423731166869402, 0.04127158597111702, 0.02638334594666958, 0.013260920532047749, -0.0059622204862535, 0.023959679529070854, -0.02264397405087948, -0.038169290870428085, -0.001468049711547792, -0.003843243233859539, -0.005477487109601498, 0.038695573806762695, 0.032407891005277634, 0.002918787533417344, 0.007305624429136515, -0.0082612419500947, ...

# %%
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %%
# 3) CHUNKANDO COM ChunkCount (divide texto a cada pontuação final, usando regex, overlap menor)
# ChunkCount(const std::string &count_unit, const int overlap = 600, const int count_threshold = 1);
count_chunker = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)
count_chunker2 = cc.ChunkCount("regex:[.!?]+", overlap=10, count_threshold=1)

# %%
# std::vector<RAGLibrary::Document> ProcessData(RAGLibrary::LoaderDataStruct &item);
count_docs = count_chunker.ProcessData(item_struct[0])
# std::vector<RAGLibrary::Document> ProcessData(const std::vector<RAGLibrary::LoaderDataStruct> &items, int max_workers = 4);
count_docs2 = count_chunker2.ProcessData(item_struct, max_workers=5)

# %%
print(f"ChunkCount from {len(count_docs)}")
print(f"ChunkCount2 from {len(count_docs2)}")
# Out:
# ChunkCount from 6914
# ChunkCount2 from 8857

# %%
print("-----------------------------------------------------------------------------------------")
print("Count")
list_count_docs = []
prev_m = None
for i, doc in enumerate(count_docs):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata

print("-----------------------------------------------------------------------------------------")
print("Count 2")
list_count_docs2 = []
prev_m = None
for i, doc in enumerate(count_docs2):
    if i > 3: break
    if doc.metadata != prev_m or prev_m is None:
        print(" METADATA =>", doc.metadata)
    print(type(doc))
    print(type(doc.page_content))
    list_count_docs2.append(doc.page_content)
    print(f"{i}:  {doc}")
    prev_m = doc.metadata
print("-----------------------------------------------------------------------------------------")
# Out:
# -----------------------------------------------------------------------------------------
# Count
#  METADATA => {'fileIdentifier': '1984'}
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 0:  Document(metadata={"fileIdentifier":"1984"}, page_content="Download free eBooks of classic literature, books and
# novels at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 1:  Document(metadata={"fileIdentifier":"1984"}, page_content="net eBook. Subscribe to our free eBooks blog
# and email newsletter.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 2:  Document(metadata={"fileIdentifier":"1984"}, page_content="ewsletter.
# 1984
# By George Orwell
#  1984
# Part One
# Free eBooks at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 3:  Document(metadata={"fileIdentifier":"1984"}, page_content="net eBook.com
# Chapter 1
# I
# t was a bright cold day in April, and the clocks were striking th...")
# -----------------------------------------------------------------------------------------
# Count 2
#  METADATA => {'fileIdentifier': 'a-christmas-carol'}
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 0:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="Download free eBooks of classic literature, books and
# novels at Planet eBook.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 1:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="net eBook. Subscribe to our free eBooks blog
# and email newsletter.")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 2:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="ewsletter.
# A Christmas Carol
# By Charles Dickens
#  Sons and Lovers
# I have endeavoured in this G...")
# <class 'purecpp_libs.purecpp_libs.RAGDocument'>
# <class 'str'>
# 3:  Document(metadata={"fileIdentifier":"a-christmas-carol"}, page_content="
# with me. May it haunt their houses pleasantly, and no one
# wish to lay it.")
# -----------------------------------------------------------------------------------------

# %%
for i, doc in enumerate(list_count_docs):
    print(f" {i}:  {doc[:70]} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")

for i, doc in enumerate(list_count_docs2):
    print(f" {i}:  {doc[:70]} ...")
    print(len(doc))
print("-----------------------------------------------------------------------------------------")
# Out:
#  0:  Download free eBooks of classic literature, books and
# novels at Plan ...
# 79
#  1:  net eBook. Subscribe to our free eBooks blog
# and email newsletter. ...
# 68
#  2:  ewsletter.
# 1984
# By George Orwell
#  1984
# Part One
# Free eBooks at Pla ...
# 80
#  3:  net eBook.com
# Chapter 1
# I
# t was a bright cold day in April, and t ...
# 104
# -----------------------------------------------------------------------------------------
#  0:  Download free eBooks of classic literature, books and
# novels at Plan ...
# 79
#  1:  net eBook. Subscribe to our free eBooks blog
# and email newsletter. ...
# 68
#  2:  ewsletter.
# A Christmas Carol
# By Charles Dickens
#  Sons and Lovers
# I ...
# 261
#  3:
# with me. May it haunt their houses pleasantly, and no one
# wish to  ...
# 77
# -----------------------------------------------------------------------------------------

# %%
# 4) USANDO ALGUMAS FUNÇÕES DE CHUNKCOMMONS MANUALMENTE
#    Exemplo:  (a) Dividir manualmente um texto e (b) Gerar embeddings via OpenAI
#    (c) Normalizar e exibir a embedding

# (a) SplitText manual
text_example = ["Este é um texto de exemplo.", "Ele será unido e fatiado em 50 chars com 10 de overlap."]
splitted = cc.SplitText(text_example, overlap=10, chunk_size=50)
print(f"[SplitText] Gerei {len(splitted)} pedaços. Primeiro pedaço:\n   {splitted[0]}")
# Out:
# [SplitText] Gerei 3 pedaços. Primeiro pedaço:
#    Este é um texto de exemplo.
# Ele será unido e fat

# %%
# 5) USANDO FUNÇÕES DE EMBEDDINGS MANUALMENTE
#    Exemplo:  (a) Gerar embeddings via OpenAI
#    (b) Normalizar e exibir a embedding
try:
    openai_emb = cc.EmbeddingOpeanAI(
        list_count_docs, # tem q ser uma lista de string
        API_KEY,
    )
    print(f"[EmbeddingOpeanAI] Embedding gerada com dim={len(openai_emb[0])} ")
    for i, item in enumerate(openai_emb):
        print(f"{i}:")
        print(type(item))
        print(item)

    cc.NormalizeEmbeddings(openai_emb[0])
except Exception as e:
    print("Não foi possível gerar embeddings com OpenAI (talvez sem chave válida):", e)
print()
# Out:
# [EmbeddingOpeanAI] Embedding gerada com dim=1536
# 0:
# <class 'list'>
# [0.010966859757900238, -0.032128263264894485, -0.010839260183274746, -0.025882594287395477, 0.003952233120799065, 0.0321819894015789, -0.01642678491771221, 0.002850846154615283, -0.01635962724685669, -0.020603995770215988, -0.002849167212843895, 0.01930113509297371, -0.012195846065878868, 0.01568804867565632, 0.016950614750385284, 0.023505210876464844, 0.01918025128543377, -0.024566302075982094, -0.012645803391933441, -0.0005213120020925999, 0.006923963315784931, 0.03032843768596649, 0.0032840135972946882, -0.03666812926530838, -0.0014472493203356862, -0.022618727758526802, 0.02358580008149147, -0.03040902689099312, 0.018978778272867203, -0.014667251147329807, 0.001997942803427577, -0.0007068352424539626, 0.01437175739556551, -0.031188055872917175, -0.0022816844284534454, 0.001152594806626439, -0.0002087136817863211, 0.016776004806160927, -0.0012608866672962904, -0.015795500949025154, 0.020348796620965004, 0.010254987515509129, 0.0012012841179966927, -0.008065644651651382, -0.03505634143948555, 0.0054968614131212234, 0.018992209807038307, -0.006316185928881168, 0.005809145048260689, 0.005933386739343405, -0.006688911467790604, 0.026822803542017937, 0.023760410025715828, -0.0333908312022686, 0.0012936260318383574, -0.0016420067986473441, 0.0014019178925082088, -0.010194545611739159, 0.008401433937251568, -0.007085141725838184, 0.007031415589153767, -1.7051770839771052e-07, -0.03545928746461868, -0.02500954456627369, -0.010066946037113667, 0.006400133017450571, -0.005503577180206776, 0.0009905766928568482, 0.001441373024135828, -0.02664819359779358, 0.0434107668697834, 0.017649054527282715, -0.016561100259423256, 0.013230075128376484, 0.020026439800858498, 0.009496104903519154, -0.0055908821523189545, 0.007145584095269442, 0.0016008727252483368, -0.006541164126247168, 0.006698985118418932, -0.01315620169043541, 0.0025167365092784166, -0.007380635943263769, 0.009462526068091393, -0.020160755142569542, 0.017716212198138237, 0.02604377269744873, -0.02419021911919117, -0.02710486575961113, -0.006944110617041588, -0.014237442053854465, 0.016681984066963196, 0.023505210876464844, -0.010221408680081367, 0.012686097994446754, -0.019233977422118187, 0.02024134434759617, 0.0015026545152068138, -0.024485712870955467, 0.017232676967978477, 0.0023454842157661915, 0.005359187722206116, -0.00519129354506731, -0.028877830132842064, 0.034680258482694626, 0.022027740254998207, -0.0013582654064521194, 0.015728343278169632, 0.015029902569949627, -0.026997413486242294, 0.0023203000891953707, 0.01720581389963627, -0.033766914159059525, 0.01772964373230934, -0.03172531723976135, -0.018038570880889893, -0.009408799931406975, -0.010953428223729134, -0.012719676829874516, -0.006312828045338392, 0.011792900040745735, 0.03403554484248161, -0.0032940872479230165, -0.007219457533210516, 0.012800266034901142, -0.013411401771008968, -0.015916384756565094, -0.027480948716402054, 0.006158364936709404, 0.020845763385295868, 0.006819868925958872, 0.022242644801735878, -0.013021886348724365, -0.029629996046423912, 0.020295070484280586, 0.00130873650778085, 0.0058326502330601215, -0.022739611566066742, -0.0016520804492756724, 0.0063833435997366905, 0.03524438291788101, -0.010087093338370323, -0.009852040559053421, -0.008374570868909359, 0.03505634143948555, 0.0038481387309730053, 0.0005049422616139054, 0.03347142040729523, 0.01255178265273571, 0.006410206668078899, 0.016346195712685585, -0.01093999668955803, -0.02282020077109337, -0.00877080112695694, 0.014573230408132076, -0.01378076896071434, 0.03693675994873047, 0.011846626177430153, -0.03134923428297043, 0.013941947370767593, 0.009596841409802437, 0.014747840352356434, -0.007783582434058189, 0.01903250440955162, 0.025573669001460075, 0.021866561844944954, -0.0038145598955452442, -0.0012843918520957232, -0.019744375720620155, -0.04813867062330246, 0.0006275051855482161, -0.019704081118106842, 0.005543871782720089, 0.008482023142278194, 0.038548544049263, -0.010738523676991463, 0.02300824224948883, -0.000669898465 ...
# 1:
# <class 'list'>
# [-0.004422593861818314, -0.04042739048600197, -0.0012565728975459933, -0.03169073536992073, -0.0004739704600069672, 0.022180801257491112, -0.01534341648221016, -0.018857071176171303, -0.016455847769975662, -0.010256076231598854, -0.005874181631952524, 0.019942371174693108, -0.01603529416024685, 0.005077165085822344, 0.002079026075080037, 0.020661382004618645, 0.010398522019386292, -0.01591319777071476, 0.004015606828033924, -0.004890629090368748, -0.014298815280199051, 0.03160933777689934, 0.006772944703698158, -0.02245212532579899, -0.005752085242420435, -0.011761928908526897, 0.010228944011032581, -0.010981869883835316, -0.0031049728859215975, -0.015614740550518036, 0.01589963212609291, 0.012338493950664997, -0.0075767445378005505, -0.016048859804868698, 0.0032033282332122326, 0.01843651942908764, 0.0024198777973651886, 0.0012404629960656166, 0.005596073344349861, -0.019983069971203804, 0.023523857817053795, 0.009035115130245686, -0.0015991204418241978, -0.00706801051273942, -0.02862476371228695, 0.0034763487055897713, 0.014583706855773926, -0.020797044038772583, -0.006474487483501434, 0.006528752390295267, 0.005026291590183973, 0.01155843585729599, 0.010174678638577461, -0.010859774425625801, 0.013878262601792812, 0.014855031855404377, 0.008424634113907814, -0.023659519851207733, 0.010045799426734447, -0.017473315820097923, -0.008621344342827797, 0.001605903496965766, -0.035435017198324203, -0.014855031855404377, -0.008492465130984783, -0.005229785107076168, -0.014407346025109291, 0.0076174428686499596, -0.017120594158768654, -0.02962866611778736, 0.03065969981253147, 0.025680890306830406, -0.03331868350505829, -0.008648477494716644, 0.017012063413858414, -0.009252174757421017, -0.009353921748697758, -0.010900473222136497, 0.005745301954448223, -0.0015541822649538517, 0.009252174757421017, 0.008723091334104538, -0.017459750175476074, -0.0039545586332678795, 0.0016355796251446009, -0.020335791632533073, 0.00738003384321928, 0.009360704571008682, -0.036927301436662674, -0.004788882099092007, -0.0016949319979175925, 0.001924710115417838, 0.02104123681783676, 0.015940330922603607, -0.019616780802607536, 0.010262859985232353, -0.02403937466442585, 0.014868597500026226, -0.010785159654915333, -0.0034203878603875637, 0.02231646329164505, 0.0011887416476383805, -0.010724111460149288, -0.011463471688330173, -0.029221678152680397, 0.02494831383228302, 0.016998497769236565, -0.008444983512163162, 0.03150080516934395, 0.02150248922407627, -0.024012243375182152, 0.00978804100304842, 0.01821945793926716, -0.029601532965898514, 0.018002398312091827, -0.026739057153463364, -0.011029352433979511, -0.0200509000569582, -0.006677981000393629, -0.011124315671622753, -0.002999834483489394, 0.023957977071404457, 0.04769889637827873, -0.0123045789077878, 0.0004230970807839185, 0.025708023458719254, -0.003081232076510787, -0.01550621073693037, -0.011972205713391304, -0.005762259941548109, 0.009374271146953106, 0.007162974216043949, 0.008512814529240131, 0.006403264589607716, -0.022302895784378052, 0.03983047604560852, -0.0026318503078073263, 0.00506699038669467, -0.029818592593073845, -0.0069526974111795425, 0.020512152463197708, 0.0377684086561203, -0.011802627705037594, -0.0048872376792132854, 0.028679028153419495, 0.027892187237739563, 0.01534341648221016, 0.017025629058480263, 0.044470131397247314, 0.01900630071759224, -0.006121765356510878, 0.0075767445378005505, 0.018233025446534157, -0.01946755312383175, -0.0017805688548833132, 0.010968304239213467, -0.001496525714173913, 0.026698358356952667, 0.005541808437556028, -0.024446362629532814, 0.009482800960540771, 0.008946934714913368, 0.014312381856143475, -0.004202142357826233, 0.006559276487678289, 0.035082291811704636, 0.010446003638207912, -0.011239629238843918, -0.007875201292335987, 0.01362728700041771, -0.013891828246414661, 0.010201811790466309, -0.033128753304481506, -0.0029574399814009666, 0.0013642548583447933, 0.04015606641769409, -0.012101084925234318, 0.01362728700041771, -0.001038 ...
# 2:
# <class 'list'>
# [0.001418618019670248, -0.024963701143860817, -0.028461799025535583, -0.035113487392663956, 0.007744842674583197, 0.01160070113837719, -0.0221678726375103, -0.004604504443705082, -0.0206043291836977, -0.027587274089455605, 0.009195758029818535, 0.04075814411044121, -0.04054613783955574, 0.0012703794054687023, 0.012256594374775887, 0.03898259624838829, 0.032039400190114975, -0.010606923140585423, 0.013873139396309853, -0.005846726708114147, 0.005187520757317543, 0.02492395043373108, -0.005336587317287922, -0.03156238794326782, 0.004269932396709919, -0.025493716821074486, 0.024340933188796043, -0.042851705104112625, 0.03174789249897003, -0.025374462828040123, -0.00011966742749791592, -0.014588659629225731, -0.014310401864349842, -0.004478625953197479, -0.028064288198947906, -0.004246744327247143, -0.0002583822642918676, -0.008175479248166084, 0.02748127281665802, -0.028064288198947906, 0.029998842626810074, 0.022817140445113182, -0.007075698580592871, 0.010176286101341248, -0.040122125297784805, 0.01886853016912937, 0.025851476937532425, -0.021359600126743317, -0.010414792224764824, 0.007108824793249369, 0.014906669035553932, 0.017225483432412148, -7.867408385209274e-06, -0.0385320819914341, -0.011786205694079399, 0.010447918437421322, 0.009016877971589565, 0.002992927795276046, -0.005064954981207848, -0.02798478677868843, 0.014045394957065582, -0.007320830598473549, -0.03039635345339775, -0.017225483432412148, -0.022817140445113182, -0.004949014168232679, -0.016788221895694733, 0.02338690683245659, -0.012713732197880745, -0.01046779379248619, 0.04727732762694359, 0.011488072574138641, -0.00014741039194632322, 0.007784593850374222, 0.01374063640832901, -0.012779983691871166, -0.017463991418480873, 0.006323740351945162, -0.003551099682226777, -0.009997406043112278, 0.010852054692804813, -0.012395722791552544, 0.011640451848506927, 0.013416001573204994, 0.005220646504312754, 0.002284032991155982, 0.003228121902793646, 0.029442327097058296, -0.028276294469833374, -0.01066654920578003, -0.021187344565987587, -0.010832179337739944, 0.0062276748940348625, 0.012680605985224247, -0.03450397029519081, 0.007936973124742508, -0.02163785696029663, 0.03384144976735115, -0.0016910787671804428, -0.03439796715974808, 0.01958405040204525, -0.009679396636784077, -0.028726806864142418, -0.0021747173741459846, -0.021743860095739365, 0.016072701662778854, 0.030846865847706795, 0.0006277363863773644, 0.010103409178555012, -0.0004939904320053756, -0.013674383983016014, -0.0018699588254094124, 0.022194374352693558, -0.032887425273656845, 0.028620803728699684, -0.03707453981041908, -0.006396617274731398, -0.020856086164712906, -0.02901831455528736, -0.020365821197628975, 0.002032275777310133, 0.03985711932182312, 0.03521949052810669, -0.007075698580592871, 0.00971914827823639, -0.004349434748291969, -0.028965312987565994, 0.004210305865854025, -0.0240494254976511, -0.005790412425994873, 0.038240574300289154, 0.008791621774435043, 0.02595747821033001, -0.0046740686520934105, -0.021518604829907417, 0.02338690683245659, -0.02166435867547989, 0.012163842096924782, -0.020551327615976334, -0.01168020348995924, 0.03389445319771767, 0.017994005233049393, 0.004647567868232727, 0.011613951064646244, 0.008917500264942646, 0.024976952001452446, 0.006744439247995615, 0.00816222932189703, 0.005992481019347906, -0.0025689159519970417, -0.0022360002622008324, 0.008791621774435043, 0.008314608596265316, 0.0018798965029418468, -0.007930347695946693, 0.029468826949596405, -0.0013507098192349076, 0.03129737824201584, -0.00610179640352726, -0.014098395593464375, 0.01244209986180067, 0.007890596985816956, 0.023068897426128387, -0.013548505492508411, 0.01753024198114872, 0.0319598987698555, 0.029097817838191986, 0.010514169931411743, -0.0010053720325231552, -0.0031834018882364035, -0.031694889068603516, 0.025162456557154655, -0.02663324773311615, 0.005263710394501686, 0.022631635889410973, 0.05424702540040016, 0.0016521557699888945, 0.010640048421919346, 0.001319240196608007, ...
# 3:
# <class 'list'>
# [-0.006091092247515917, -0.020221762359142303, -0.013085060752928257, -0.05175602808594704, 0.006924260873347521, 0.01951805129647255, -0.015853436663746834, -0.012553957290947437, -0.03154754266142845, -0.01779196411371231, 0.00846446119248867, 0.020659923553466797, -0.024497145786881447, 0.00388701306656003, -0.0005821391241624951, 0.0013742301380261779, 0.0030455461237579584, -0.02282417006790638, 0.0015991191612556577, -0.006137563847005367, -0.006336727645248175, 0.03452172130346298, -0.009227922186255455, -0.008643708191812038, -0.0014439374208450317, -0.005291117820888758, 0.007986467331647873, -0.025360187515616417, 0.03170687332749367, -0.01905333437025547, -0.0002964635787066072, -0.0298480112105608, -0.009042035788297653, -0.012819509021937847, -0.024390924721956253, -0.019239220768213272, -0.00651597511023283, -0.02421831525862217, 0.004069579765200615, -0.022200122475624084, 0.0066122375428676605, 0.019942933693528175, -0.00867026299238205, -0.0018837574170902371, -0.04370981082320213, 0.03465449810028076, 0.032184865325689316, -0.000729852297808975, -0.00325964717194438, 0.02581162564456463, 0.017154639586806297, 0.02652861550450325, 0.005377422086894512, -0.028148481622338295, -0.0029957552906125784, 0.012122435495257378, 0.009805496782064438, 0.010097603313624859, -0.01068845670670271, -0.012195462360978127, -0.013609524816274643, -0.00965944305062294, -0.03367195650935173, -0.018150459975004196, 0.007754109799861908, -0.01990310102701187, -0.01917283423244953, 0.00028961733914911747, -0.01601276732981205, -0.002650537993758917, 0.04689643159508705, 0.01141208503395319, -0.005563308484852314, 0.013509943149983883, 0.011206282302737236, 0.0005510197952389717, -0.0039235264994204044, -0.006273658946156502, 0.004949219990521669, -0.0028480421751737595, 0.01958443783223629, -0.02870613895356655, -0.007860330864787102, 0.014963839203119278, 0.00873665139079094, -0.011624526232481003, -0.008046216331422329, 0.006924260873347521, -0.022412564605474472, 0.006091092247515917, 0.0198499895632267, -0.0026289618108421564, 0.02448386698961258, 0.02031470648944378, -0.010754844173789024, 0.011046950705349445, -0.012494208291172981, 0.0037310014013201, 0.0015036865370348096, -0.022917112335562706, 0.026369284838438034, -0.008656986057758331, -0.01422029361128807, 0.0010995500488206744, -0.028414033353328705, 0.00588860921561718, 0.03229108825325966, 0.0002987456682603806, 0.002565893344581127, -0.01452567894011736, -0.018601898103952408, 0.024908749386668205, 0.007501835934817791, -0.029343463480472565, 0.016450928524136543, -0.03478727489709854, -0.002384986262768507, -0.022266510874032974, -0.005945038981735706, -0.0015211133286356926, -0.005500239785760641, 0.04758686572313309, 0.010515847243368626, 0.005301075987517834, 0.001948485616594553, -0.012202100828289986, -0.010130797512829304, -0.014127351343631744, -0.006197312846779823, -0.00965944305062294, 0.023594269528985023, 0.008491015993058681, 0.018442565575242043, -0.002550956094637513, -0.02878580614924431, 0.02732527069747448, -0.009300949051976204, 0.018017683178186417, -0.03327362984418869, -0.010807954706251621, 0.013277585618197918, 0.02156279794871807, -0.014392903074622154, -0.006432990077883005, 0.01426012720912695, 0.03130854666233063, 0.025944402441382408, 0.010316683910787106, 0.01528250053524971, -0.0001763429318089038, 0.025506241247057915, 0.010489292442798615, 0.000314720266032964, 0.01144527830183506, 0.010343238711357117, 0.013244391418993473, -0.016185376793146133, 0.016650091856718063, -0.006008107215166092, -0.005815582349896431, 0.016318151727318764, 0.00820554792881012, 0.030140118673443794, -0.010402988642454147, 0.02327560819685459, 0.025944402441382408, -0.0007194791687652469, -0.014127351343631744, 0.003850499866530299, 0.00651929434388876, -0.02923724241554737, -0.0066620283760130405, -0.019079890102148056, 0.016052599996328354, 0.0067549715749919415, 0.021669019013643265, 0.017765410244464874, 0.02204079180955887, -0.013914909213781357, -0 ...
